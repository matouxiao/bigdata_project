# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from datetime import datetime, timedelta
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# 确保图形在Jupyter Notebook中显示
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
# 读取CSV文件
df_apple1 = pd.read_csv("688981_posts_data.csv")
df_apple2 = pd.read_csv("000524_posts_data.csv")
df_apple3 = pd.read_csv("002475_posts_data.csv")

# %%
# 所有时间都是 2025 年的
df_apple1['Date'] = "2025-" + df_apple1['Date']
df_apple1['Date'] = pd.to_datetime(df_apple1['Date']).dt.date
df_apple2['Date'] = "2025-" + df_apple2['Date']
df_apple2['Date'] = pd.to_datetime(df_apple2['Date']).dt.date
df_apple3['Date'] = "2025-" + df_apple3['Date']
df_apple3['Date'] = pd.to_datetime(df_apple3['Date']).dt.date
# df_apple['Date'] = pd.to_datetime(df_apple['Date'], format="%Y-%m-%d %H:%M")
df_apple1.head()
df_apple2.head()
df_apple3.head()
# Out:
#    read_count            title        Date
# 0           1  继续跌啊，不要企稳，赶紧向下。  2025-05-07
# 1           1     35不知道需要等多久回本  2025-05-07
# 2          69              真牛逼  2025-05-07
# 3           1   跌吧，让暴风雨来得更猛烈些吧  2025-05-07
# 4           3          跌呀怎么不跌了  2025-05-07

# %%
import re
# 简单清洗文本（去除特殊符号、空格等）
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', str(text))  # 去除非字母数字字符
    text = text.strip()  # 去除首尾空格
    return text
df_apple1["title"] = df_apple1["title"].apply(clean_text)
df_apple2["title"] = df_apple2["title"].apply(clean_text)
df_apple3["title"] = df_apple3["title"].apply(clean_text)
print(df_apple1.head())  # 检查清洗后的数据
print(df_apple2.head())  # 检查清洗后的数据
print(df_apple3.head())  # 检查清洗后的数据
# Out:
#    read_count                                  title        Date
# 0       13546                            A股进口替代50强出炉  2025-05-02
# 1         188                 一起举报那个满融满仓中芯国际刷屏可耻把他封了  2025-05-07
# 2         116                        明天的一季度业绩不知道什么样子  2025-05-07
# 3        1042  去年以来已经涨的够多了现可以离场了大盘上20天线中芯跌破20天线君子不立危  2025-04-25
# 4          18                             2收盘明天可以起飞了  2025-05-07
#    read_count               title        Date
# 0          13   真是无语它大爷你敢涨5个点我就敢卖  2025-05-07
# 1           1         今年就这样了垃圾不敢拉  2025-05-07
# 2          86             16块买的有吗  2025-05-07
# 3          39           今天进来了陪兄弟们  2025-05-07
# 4         122  岭南控股1283买的什么时候能涨起来  2025-05-07
#    read_count          title        Date
# 0           1   继续跌啊不要企稳赶紧向下  2025-05-07
# 1           1   35不知道需要等多久回本  2025-05-07
# 2          69            真牛逼  2025-05-07
# 3           1  跌吧让暴风雨来得更猛烈些吧  2025-05-07
# 4           3        跌呀怎么不跌了  2025-05-07

# %%
# 按照股票代码合并数据, 加上股票代码一列
df_apple1['ticker'] = '688981'
df_apple2['ticker'] = '000524'
df_apple3['ticker'] = '002475'
df_apple = pd.concat([df_apple1, df_apple2, df_apple3], ignore_index=True)
df_apple = df_apple[['ticker', 'Date', 'title', 'read_count']]
df_apple['read_count'] = df_apple['read_count'].astype(int)
df_apple.head()
# Out:
#    ticker        Date                                  title  read_count
# 0  688981  2025-05-02                            A股进口替代50强出炉       13546
# 1  688981  2025-05-07                 一起举报那个满融满仓中芯国际刷屏可耻把他封了         188
# 2  688981  2025-05-07                        明天的一季度业绩不知道什么样子         116
# 3  688981  2025-04-25  去年以来已经涨的够多了现可以离场了大盘上20天线中芯跌破20天线君子不立危        1042
# 4  688981  2025-05-07                             2收盘明天可以起飞了          18

# %%
# 情感分析
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizer
# 使用专为中文设计的情感分析模型
model_name = "yiyanghkust/finbert-tone-chinese"  # 金融情感分析模型
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
# 创建中文情感分析pipeline
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)
# 分析中文文本
results_apple = []
for tweet in df_apple["title"]:
    try:
        sentiment = sentiment_pipeline(tweet)[0]
        # 转换标签格式以匹配后续处理代码
        # 这个模型的标签是 "positive" 和 "negative"
        # 股票代码也加上
        results_apple.append((tweet, [sentiment], df_apple.loc[df_apple['title'] == tweet, 'ticker'].values[0]))
    except Exception as e:
        # 处理可能的错误，比如文本太长或格式问题
        print(f"处理文本时出错: {tweet}")
        print(e)
        # 股票代码
        results_apple.append((tweet, [{"label": "neutral", "score": 0.5}], df_apple.loc[df_apple['title'] == tweet, 'ticker'].values[0]))
results_apple
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.04k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/409M [00:00<?, ?B/s]
# Device set to use mps:0
# [('A股进口替代50强出炉',
#   [{'label': 'Neutral', 'score': 0.9952408075332642}],
#   '688981'),
#  ('一起举报那个满融满仓中芯国际刷屏可耻把他封了',
#   [{'label': 'Neutral', 'score': 0.9937096834182739}],
#   '688981'),
#  ('明天的一季度业绩不知道什么样子',
#   [{'label': 'Neutral', 'score': 0.6077010631561279}],
#   '688981'),
#  ('去年以来已经涨的够多了现可以离场了大盘上20天线中芯跌破20天线君子不立危',
#   [{'label': 'Positive', 'score': 0.7967190146446228}],
#   '688981'),
#  ('2收盘明天可以起飞了', [{'label': 'Neutral', 'score': 0.9914097189903259}], '688981'),
#  ('满融满仓中芯国际是托大家一起举报',
#   [{'label': 'Neutral', 'score': 0.9962316155433655}],
#   '688981'),
#  ('港股不起来他一辈子不会动',
#   [{'label': 'Neutral', 'score': 0.9869755506515503}],
#   '688981'),
#  ('一季报看着有问题了', [{'label': 'Negative', 'score': 0.9805811643600464}], '688981'),
#  ('前天收盘前没买到赤峰黄金今天转战抄底拉升鹏欣资源必须封板',
#   [{'label': 'Neutral', 'score': 0.9973517656326294}],
#   '688981'),
#  ('中芯阴跌不止大家还坚守吗',
#   [{'label': 'Negative', 'score': 0.7802771329879761}],
#   '688981'),
#  ('股', [{'label': 'Neutral', 'score': 0.9794074296951294}], '688981'),
#  ('欢迎大主播陆老割进场', [{'label': 'Neutral', 'score': 0.9928905963897705}], '688981'),
#  ('你们有谁在108元买的我在108买的现在补又不想补割肯定不割了耐心等待等',
#   [{'label': 'Neutral', 'score': 0.9910733103752136}],
#   '688981'),
#  ('假设谜圆崩掉三成金价至少上涨一倍晓程科技在黄金储量和产量都不变情况下股价就能',
#   [{'label': 'Neutral', 'score': 0.9966989159584045}],
#   '688981'),
#  ('我是一个光明磊落的人以前所有预测错误的贴子全部保留以警醒自己错误的预测主要',
#   [{'label': 'Neutral', 'score': 0.9769500494003296}],
#   '688981'),
#  ('今天的最佳买点出现了', [{'label': 'Neutral', 'score': 0.9889386892318726}], '688981'),
#  ('能随便说说么再大的利好也刺激不了你若能全年保持每天涨一个点也不错只要你不拉',
#   [{'label': 'Positive', 'score': 0.9741705656051636}],
#   '688981'),
#  ('股价创10日新高资金确是流出状态你们觉得是主力边卖边拉还是主力边收边拉',
#   [{'label': 'Neutral', 'score': 0.9900246858596802}],
#   '688981'),
#  ('一手好牌打稀烂', [{'label': 'Neutral', 'score': 0.9867905974388123}], '688981'),
#  ('没有一次不高开低走', [{'label': 'Neutral', 'score': 0.9924184083938599}], '688981'),
#  ('饨刀子割肉', [{'label': 'Neutral', 'score': 0.9900873303413391}], '688981'),
#  ('激进调仓6只基金重仓股大换血 AI硬件化路线图曝光',
#   [{'label': 'Neutral', 'score': 0.9969286322593689}],
#   '688981'),
#  ('那帮人就会拉银行稳大盘了',
#   [{'label': 'Neutral', 'score': 0.9672343730926514}],
#   '688981'),
#  ('f物一个', [{'label': 'Neutral', 'score': 0.9923366904258728}], '688981'),
#  ('中芯国际5月起航相信你可以的',
#   [{'label': 'Neutral', 'score': 0.9970329999923706}],
#   '688981'),
#  ('磨叽七个月了没戏了都跑了',
#   [{'label': 'Neutral', 'score': 0.9655887484550476}],
#   '688981'),
#  ('中芯国际今天收阳线', [{'label': 'Neutral', 'score': 0.7726840376853943}], '688981'),
#  ('寒又涨了130元呜呜', [{'label': 'Neutral', 'score': 0.9594036340713501}], '688981'),
#  ('一季度是盈利的吗', [{'label': 'Neutral', 'score': 0.9831798076629639}], '688981'),
#  ('破100', [{'label': 'Neutral', 'score': 0.9787780046463013}], '688981'),
#  ('海市蜃楼', [{'label': 'Neutral', 'score': 0.9894130825996399}], '688981'),
#  ('怎么都不涨', [{'label': 'Neutral', 'score': 0.9496389627456665}], '688981'),
#  ('拖累整个科创50', [{'label': 'Negative', 'score': 0.9985941052436829}], '688981'),
#  ('啊你个', [{'label': 'Neutral', 'score': 0.9571235775947571}], '688981'),
#  ('高开低走大A永恒不变的主题',
#   [{'label': 'Neutral', 'score': 0.9966112971305847}],
#   '688981'),
#  ('真nm小可爱这票废了', [{'label': 'Neutral', 'score': 0.9777562618255615}], '688981'),
#  ('快跑大家一定要听话', [{'label': 'Neutral', 'score': 0.9890483021736145}], '688981'),
#  ('非常漂亮高开低走加油加油加油',
#   [{'label': 'Neutral', 'score': 0.6988992094993591}],
#   '688981'),
#  ('大家有没有看华为建厂的事情是不是以后不需要中芯国际了',
#   [{'label': 'Neutral', 'score': 0.997340738773346}],
#   '688981'),
#  ('中芯国际一切一切的科技最终都要中芯国际出品',
#   [{'label': 'Neutral', 'score': 0.9973437190055847}],
#   '688981'),
#  ('一季报有利空主力出货破80再看吧',
#   [{'label': 'Positive', 'score': 0.5205460786819458}],
#   '688981'),
#  ('今天买了点底仓明天继续加这波看98',
#   [{'label': 'Neutral', 'score': 0.9956814050674438}],
#   '688981'),
#  ('有人建议剔除全村唯一的希望不知道你们在想啥拿住',
#   [{'label': 'Neutral', 'score': 0.9937334656715393}],
#   '688981'),
#  ('中芯国际什么时候发布一季报规定的时间都过了',
#   [{'label': 'Neutral', 'score': 0.9951032400131226}],
#   '688981'),
#  ('旋极信息旗下控股子公司旋极星源也是IP授权商技术也相当厉害旋极信息既有软件又',
#   [{'label': 'Neutral', 'score': 0.99700528383255}],
#   '688981'),
#  ('A股半导体行业盈利王  罕见易主',
#   [{'label': 'Neutral', 'score': 0.9966700673103333}],
#   '688981'),
#  ('既然我都认为趋势开始上升了那还有什么可怕的呢呵呵买就是了',
#   [{'label': 'Neutral', 'score': 0.9805172085762024}],
#   '688981'),
#  ('要做好突破千元的思想准备',
#   [{'label': 'Neutral', 'score': 0.868431031703949}],
#   '688981'),
#  ('已加仓看120', [{'label': 'Neutral', 'score': 0.9868898391723633}], '688981'),
#  ('汤姆猫算正宗鸿蒙概念吧',
#   [{'label': 'Neutral', 'score': 0.9926549196243286}],
#   '688981'),
#  ('垃圾票啊99成本放我出来啊',
#   [{'label': 'Neutral', 'score': 0.9778575897216797}],
#   '688981'),
#  ('这票真是个笑话韭菜池子',
#   [{'label': 'Neutral', 'score': 0.9918597340583801}],
#   '688981'),
#  ('骂不动了你们上吧继续躺尸三年这家伙补一次套一次后年能给解套了解套',
#   [{'label': 'Neutral', 'score': 0.9909191131591797}],
#   '688981'),
#  ('中芯国际港股公告证券变动月报表',
#   [{'label': 'Neutral', 'score': 0.9970347881317139}],
#   '688981'),
#  ('向新发力 提质筑基科创板公司2024年度经营业绩概览',
#   [{'label': 'Neutral', 'score': 0.9945699572563171}],
#   '688981'),
#  ('中芯玩了国际还有希望吗大家谈谈吧',
#   [{'label': 'Neutral', 'score': 0.9961521029472351}],
#   '688981'),
#  ('别只知道一个劲地骂中芯是调控大盘的股票也是调控科创板和半导体板块的股票科创',
#   [{'label': 'Neutral', 'score': 0.9978378415107727}],
#   '688981'),
#  ('主力到底卖完了没有有本事一辈子都别进来',
#   [{'label': 'Neutral', 'score': 0.9906324148178101}],
#   '688981'),
#  ('今天上影线明天来个低开高走下影线配合技术指标后天拉升尾盘公布业绩',
#   [{'label': 'Neutral', 'score': 0.9926482439041138}],
#   '688981'),
#  ('主力净流出近1个亿减仓为主',
#   [{'label': 'Neutral', 'score': 0.9186103940010071}],
#   '688981'),
#  ('最近手里的股票涨停不断',
#   [{'label': 'Positive', 'score': 0.9963762164115906}],
#   '688981'),
#  ('量化狗天天', [{'label': 'Neutral', 'score': 0.9920207858085632}], '688981'),
#  ('在同花顺里搜中芯的机构持股比例是零',
#   [{'label': 'Neutral', 'score': 0.9979422688484192}],
#   '688981'),
#  ('为什么阴跌有你涨与你没关系',
#   [{'label': 'Neutral', 'score': 0.9942547678947449}],
#   '688981'),
#  ('每次半导体板块都是你拖后腿建议剔除板块',
#   [{'label': 'Neutral', 'score': 0.9956530332565308}],
#   '688981'),
#  ('别说100了90都是你过不去的鸿沟',
#   [{'label': 'Neutral', 'score': 0.9813073873519897}],
#   '688981'),
#  ('傻雕中芯指数和板块都跑不赢',
#   [{'label': 'Neutral', 'score': 0.9898440837860107}],
#   '688981'),
#  ('科技股半导体算走的弱的因为这个大拉基拖后腿',
#   [{'label': 'Neutral', 'score': 0.9753647446632385}],
#   '688981'),
#  ('同花顺里显示中芯国际机构持股为零',
#   [{'label': 'Neutral', 'score': 0.9981638789176941}],
#   '688981'),
#  ('两市基金持仓前50名没有这货了犊子了',
#   [{'label': 'Neutral', 'score': 0.9937028288841248}],
#   '688981'),
#  ('大家千万别买这个股我也割肉清仓这个股',
#   [{'label': 'Neutral', 'score': 0.9972056746482849}],
#   '688981'),
#  ('不会收盘集合竞价又来个9000精准把控吧',
#   [{'label': 'Neutral', 'score': 0.986200213432312}],
#   '688981'),
#  ('两个月120多亿的净流出就问你怕不怕40多建仓的主力无论怎么卖都是赚的',
#   [{'label': 'Neutral', 'score': 0.9448935389518738}],
#   '688981'),
#  ('可控核聚变非晶合金电机光刻机钱景一片光明',
#   [{'label': 'Neutral', 'score': 0.5161361694335938}],
#   '688981'),
#  ('明天高开2个点', [{'label': 'Neutral', 'score': 0.8772162795066833}], '688981'),
#  ('你就是个大笑话', [{'label': 'Neutral', 'score': 0.9659913182258606}], '688981'),
#  ('我希望大家要去研究每个上市公司总负债中芯国际是我看到唯数不多比去年减少的公司',
#   [{'label': 'Neutral', 'score': 0.9955033659934998}],
#   '688981'),
#  ('中国最早在明年就能完成EUV原型机的验证然后启动小批量生产到2030年负责',
#   [{'label': 'Neutral', 'score': 0.9974478483200073}],
#   '688981'),
#  ('中芯国际本周融资净偿还248013万元居半导体板块第十五',
#   [{'label': 'Neutral', 'score': 0.990614652633667}],
#   '688981'),
#  ('看空做空中芯国际都会你看李大霄就获得很滋润',
#   [{'label': 'Neutral', 'score': 0.9712076783180237}],
#   '688981'),
#  ('什么时候盘到60周线什么时候才有行情',
#   [{'label': 'Neutral', 'score': 0.99673992395401}],
#   '688981'),
#  ('芯片在中国有5万亿元人民币的市场额估计短期内中芯国际至少能拿到其中的20',
#   [{'label': 'Neutral', 'score': 0.9980756044387817}],
#   '688981'),
#  ('高成长的公司投入大量的利润去建厂买设备和聘请人才扩大生产这种公司看它的PE没有',
#   [{'label': 'Neutral', 'score': 0.992711067199707}],
#   '688981'),
#  ('华为PC芯片即将发布国产芯片从设计到制造再到终端将全面爆发',
#   [{'label': 'Neutral', 'score': 0.9972208738327026}],
#   '688981'),
#  ('A股进口替代50强出炉 AI芯片光刻胶科学仪器谁空间更大高成长高科技高胜率',
#   [{'label': 'Neutral', 'score': 0.952174186706543}],
#   '688981'),
#  ('年初港口连A股的13都不到',
#   [{'label': 'Neutral', 'score': 0.9948974251747131}],
#   '688981'),
#  ('突926', [{'label': 'Neutral', 'score': 0.9890350103378296}], '688981'),
#  ('于无声处听惊雷随着中国高端光刻机的到来中芯终有一飞冲天之日',
#   [{'label': 'Neutral', 'score': 0.72479248046875}],
#   '688981'),
#  ('这货就是扶不起的阿斗呵呵',
#   [{'label': 'Neutral', 'score': 0.9674769043922424}],
#   '688981'),
#  ('改名叫不争气吧', [{'label': 'Neutral', 'score': 0.983526885509491}], '688981'),
#  ('50强', [{'label': 'Neutral', 'score': 0.9801828861236572}], '688981'),
#  ('现在已经是连续横盘10天了该是选择方向突破了如果我是主力我可能不会直接向上',
#   [{'label': 'Neutral', 'score': 0.9944537281990051}],
#   '688981'),
#  ('追踪张坤刘彦春等明星基金经理调仓路线重回白酒 加仓科技',
#   [{'label': 'Neutral', 'score': 0.9965721368789673}],
#   '688981'),
#  ('五一期间人氏币升值利好旅游消费房地产王府井原首旅股价最高80元现价12',
#   [{'label': 'Positive', 'score': 0.9985589385032654}],
#   '688981'),
#  ('中芯国际融资净偿还364683万元融资余额7222亿元0430',
#   [{'label': 'Neutral', 'score': 0.9972403049468994}],
#   '688981'),
#  ('达到GB200的80我怎么有点不相信呢',
#   [{'label': 'Neutral', 'score': 0.9650716185569763}],
#   '688981'),
#  ('摩根士丹利将台积电列为首选个股那我大A呢',
#   [{'label': 'Neutral', 'score': 0.9885504841804504}],
#   '688981'),
#  ('上交所科创板2024年研发投入总额达到168078亿元 超过净利润的25倍',
#   [{'label': 'Positive', 'score': 0.9942331910133362}],
#   '688981'),
#  ('中芯国际市销率分别是2570倍1445倍20倍668倍1005倍',
#   [{'label': 'Neutral', 'score': 0.9981258511543274}],
#   '688981'),
#  ('磨叽半年了不知是到一楼还是30楼',
#   [{'label': 'Neutral', 'score': 0.9854030609130859}],
#   '688981'),
#  ('中芯国际虽然是明星股但有六十亿股的港股拖累估值难以有效提升长期投资首选应该',
#   [{'label': 'Negative', 'score': 0.9881657361984253}],
#   '688981'),
#  ('大好的青春浪费在你这身上',
#   [{'label': 'Neutral', 'score': 0.7991546988487244}],
#   '688981'),
#  ('再次提示买入机会银行业绩普遍下降股价大幅调整为半导体和其他科技股提供血包',
#   [{'label': 'Negative', 'score': 0.9494136571884155}],
#   '688981'),
#  ('以点带面 稳链强链 2024年度科创板公司共实现营业收入1422170亿元',
#   [{'label': 'Neutral', 'score': 0.9899404644966125}],
#   '688981'),
#  ('沪市上市公司2024年成绩单',
#   [{'label': 'Neutral', 'score': 0.9959781169891357}],
#   '688981'),
#  ('特朗普修改AI芯片出口管制利好半导体芯片节后大涨',
#   [{'label': 'Positive', 'score': 0.9985816478729248}],
#   '688981'),
#  ('蒸汽机头把半导体这列火车带废了',
#   [{'label': 'Neutral', 'score': 0.993800938129425}],
#   '688981'),
#  ('涨难跌易但我还是决定跟随公募资金的步伐今天再次满仓中芯希望中芯一路长阳谢',
#   [{'label': 'Positive', 'score': 0.8623448610305786}],
#   '688981'),
#  ('上交所2024年度科创板五成公司实现净利润增长',
#   [{'label': 'Positive', 'score': 0.9989483952522278}],
#   '688981'),
#  ('简单分析2024年报', [{'label': 'Neutral', 'score': 0.9957245588302612}], '688981'),
#  ('以前没有5点差价不做今天赚你一元都好难温水煮蛙逗你玩吧',
#   [{'label': 'Neutral', 'score': 0.9817990660667419}],
#   '688981'),
#  ('中芯国际SH688981',
#   [{'label': 'Neutral', 'score': 0.9971179962158203}],
#   '688981'),
#  ('科创板硬卡替组合拳显效多个关键领域自给率及国产化率显著提升',
#   [{'label': 'Positive', 'score': 0.9985741376876831}],
#   '688981'),
#  ('看头部几个权重股直接封板半导体ETF159813这次真的要起来了科技行情跳得',
#   [{'label': 'Neutral', 'score': 0.9949979782104492}],
#   '688981'),
#  ('今天日线MACD终于完成死叉意味着底部钝化形成调整进入尾声近两周连续阴跌',
#   [{'label': 'Negative', 'score': 0.7591322064399719}],
#   '688981'),
#  ('一只', [{'label': 'Neutral', 'score': 0.9892186522483826}], '688981'),
#  ('赚几块钱太难了', [{'label': 'Neutral', 'score': 0.7550954818725586}], '688981'),
#  ('总算红盘一天', [{'label': 'Neutral', 'score': 0.9889989495277405}], '688981'),
#  ('半导体板块拉升你躺平半导体调整你一马当先跳水',
#   [{'label': 'Neutral', 'score': 0.9956619143486023}],
#   '688981'),
#  ('可以看看乖宝宠物有支撑搏明天反弹我没有卖中芯买其他票的魄力交给大家了',
#   [{'label': 'Neutral', 'score': 0.9947239756584167}],
#   '688981'),
#  ('黑芯国际一生黑', [{'label': 'Neutral', 'score': 0.9935947060585022}], '688981'),
#  ('不会绿了收盘吧', [{'label': 'Neutral', 'score': 0.9819006323814392}], '688981'),
#  ('报告组织拉3个板我就生3胎',
#   [{'label': 'Neutral', 'score': 0.9959335923194885}],
#   '688981'),
#  ('这货这不涨不行被港芯倒过来拉着往上走情不由己呀',
#   [{'label': 'Neutral', 'score': 0.9923836588859558}],
#   '688981'),
#  ('一阳吞三阴', [{'label': 'Neutral', 'score': 0.9829612374305725}], '688981'),
#  ('慢慢涨才是真的涨呀', [{'label': 'Neutral', 'score': 0.9242129921913147}], '688981'),
#  ('拉起来吧让散户们挣点钱吧一根大阳就敢出去胡吃海喝大宝剑全套三个涨停就敢三胎',
#   [{'label': 'Neutral', 'score': 0.9951399564743042}],
#   '688981'),
#  ('大家就在旅游途中等利好消息吧这走势绝对是有利好消息等着假期发布了',
#   [{'label': 'Positive', 'score': 0.9486037492752075}],
#   '688981'),
#  ('我们支持希望你也别跪', [{'label': 'Neutral', 'score': 0.9834453463554382}], '688981'),
#  ('4月29日晚新华保险公告称公司拟出资不超过100亿元认购由国丰兴华北京私',
#   [{'label': 'Neutral', 'score': 0.9972352385520935}],
#   '688981'),
#  ('坚守红利却不敌基准 风格稳定大于短期涨跌基金一季报大透视',
#   [{'label': 'Neutral', 'score': 0.9845280051231384}],
#   '688981'),
#  ('我上次91卖出买入了别的股赚了不到1个点今天买了东方财富明天大概率月底收',
#   [{'label': 'Neutral', 'score': 0.9939736723899841}],
#   '688981'),
#  ('好家伙村龙中芯国际连跌9天了谁家部将在出货调仓作为科创芯片ETF的第一',
#   [{'label': 'Neutral', 'score': 0.9898930191993713}],
#   '688981'),
#  ('4月29日科创板主力资金净流出912亿元',
#   [{'label': 'Negative', 'score': 0.6140896081924438}],
#   '688981'),
#  ('大宗交易中芯国际成交220万元成交价8800元0429',
#   [{'label': 'Neutral', 'score': 0.997489333152771}],
#   '688981'),
#  ('良率已经解决', [{'label': 'Neutral', 'score': 0.9908533692359924}], '688981'),
#  ('炼完后下来就是化骨大法要不大家都骨头渣渣都给化完',
#   [{'label': 'Neutral', 'score': 0.9909205436706543}],
#   '688981'),
#  ('还龙头我看就是个垃圾', [{'label': 'Neutral', 'score': 0.979721188545227}], '688981'),
#  ('散户不走主力不抬散户割肉主力就拉散户散尽直接涨停拉到高位高位出货',
#   [{'label': 'Neutral', 'score': 0.9932997226715088}],
#   '688981'),
#  ('看好明天继续收阴练习九阴白骨掌',
#   [{'label': 'Positive', 'score': 0.9970209002494812}],
#   '688981'),
#  ('这种阴跌出货模式背后就是季报不及预期的利空接着还有三个大阴线破70',
#   [{'label': 'Neutral', 'score': 0.707994282245636}],
#   '688981'),
#  ('都在等中报预期', [{'label': 'Neutral', 'score': 0.9933233857154846}], '688981'),
#  ('统一回复一下折价15出售的大宗交易就是某些非流通股必定还有半年以上的销售期',
#   [{'label': 'Neutral', 'score': 0.9975614547729492}],
#   '688981'),
#  ('n3', [{'label': 'Neutral', 'score': 0.9817439317703247}], '688981'),
#  ('', [{'label': 'Neutral', 'score': 0.9767643809318542}], '688981'),
#  ('年报一季报不是截止到4月30日吗',
#   [{'label': 'Neutral', 'score': 0.9960595369338989}],
#   '688981'),
#  ('这是个好票也许一年后会出业绩',
#   [{'label': 'Positive', 'score': 0.847968578338623}],
#   '688981'),
#  ('我已满融满仓我已满融满仓231买入宁德时代占25仓位88以下买入中芯',
#   [{'label': 'Neutral', 'score': 0.9723877310752869}],
#   '688981'),
#  ('再跌一天周五止跌大家稍安勿躁哈',
#   [{'label': 'Neutral', 'score': 0.9687861800193787}],
#   '688981'),
#  ('解密主力资金出逃股 连续5日净流出502股',
#   [{'label': 'Neutral', 'score': 0.9931936860084534}],
#   '688981'),
#  ('连续绿多少天了明天一绿到底算了',
#   [{'label': 'Neutral', 'score': 0.9923801422119141}],
#   '688981'),
#  ('中芯国际已经连跌一个星期了应该快戴帽子了',
#   [{'label': 'Negative', 'score': 0.8821375966072083}],
#   '688981'),
#  ('十来年从未分过红的你以为是善茬只有索取绝无回报',
#   [{'label': 'Neutral', 'score': 0.9915522933006287}],
#   '688981'),
#  ('一路下跌不如早点卖', [{'label': 'Neutral', 'score': 0.9088422060012817}], '688981'),
#  ('要大跌', [{'label': 'Neutral', 'score': 0.9349769949913025}], '688981'),
#  ('明天也许真得走了', [{'label': 'Neutral', 'score': 0.9723066687583923}], '688981'),
#  ('还好早上开盘就卖了去兆易创新这废股一直阴跌',
#   [{'label': 'Negative', 'score': 0.9512653350830078}],
#   '688981'),
#  ('连着买了九天都被套哎凶多吉少啊',
#   [{'label': 'Neutral', 'score': 0.9057058095932007}],
#   '688981'),
#  ('赌中芯国际至少50根阴线组合',
#   [{'label': 'Neutral', 'score': 0.9947381615638733}],
#   '688981'),
#  ('老夫说的下限85敢越雷池半步',
#   [{'label': 'Neutral', 'score': 0.9910827875137329}],
#   '688981'),
#  ('中芯的机会在下半年等光刻机消息出来吧属于中国半导体的deepseek时刻',
#   [{'label': 'Neutral', 'score': 0.9969251751899719}],
#   '688981'),
#  ('大家猜猜25年会不会再破77',
#   [{'label': 'Neutral', 'score': 0.9641437530517578}],
#   '688981'),
#  ('一季报今天晚上集中公布很多散户又吓鸟了',
#   [{'label': 'Neutral', 'score': 0.933746337890625}],
#   '688981'),
#  ('近230亿折旧毛利率创九年新低中芯国际陷入成本拉锯战',
#   [{'label': 'Negative', 'score': 0.9139111638069153}],
#   '688981'),
#  ('大宗交易中芯国际成交29097万元折价3000428',
#   [{'label': 'Neutral', 'score': 0.9977319240570068}],
#   '688981'),
#  ('扩大对外开放促进内需消费维护资本市场稳定是应对外部环境变化之重中之重坚决',
#   [{'label': 'Neutral', 'score': 0.7575880289077759}],
#   '688981'),
#  ('我没有想要当世界首富但是我讲话是经过深思和研究的是有依据的可信的我是一个',
#   [{'label': 'Neutral', 'score': 0.9934993982315063}],
#   '688981'),
#  ('不是说这不是好公司只是真的贵了透支未来3年涨幅台积电才21倍PE',
#   [{'label': 'Neutral', 'score': 0.9839925169944763}],
#   '688981'),
#  ('基金经理下调持股集中度释放什么信号',
#   [{'label': 'Negative', 'score': 0.6444990038871765}],
#   '688981'),
#  ('多期待能大涨啊可是从成交量消息面和技术面都不支持哎持股过节或者节后第',
#   [{'label': 'Neutral', 'score': 0.9898000359535217}],
#   '688981'),
#  ('太把自己当盘菜了高看你了',
#   [{'label': 'Neutral', 'score': 0.941253662109375}],
#   '688981'),
#  ('中芯国际大宗交易成交340万股 成交额29097万元',
#   [{'label': 'Neutral', 'score': 0.997190535068512}],
#   '688981'),
#  ('中芯国际会不会像中国石油一样一路下跌它最后跌到几元钱十元一下',
#   [{'label': 'Negative', 'score': 0.5806848406791687}],
#   '688981'),
#  ('多股获机构看好目标涨幅最大5513217',
#   [{'label': 'Positive', 'score': 0.9970048069953918}],
#   '688981'),
#  ('多股获机构看好目标涨幅最大336728',
#   [{'label': 'Positive', 'score': 0.9977726340293884}],
#   '688981'),
#  ('多股获机构看好目标涨幅最大5405218',
#   [{'label': 'Positive', 'score': 0.9976845979690552}],
#   '688981'),
#  ('中芯国际是一个脚踏实地兢兢业业的干实事的好公司我是绝对相信他们的实力和技术',
#   [{'label': 'Positive', 'score': 0.9724931120872498}],
#   '688981'),
#  ('阴跌出货利空来袭即将开始三个大阴线破80指日可待',
#   [{'label': 'Neutral', 'score': 0.8822957873344421}],
#   '688981'),
#  ('热门投资方向创新高', [{'label': 'Neutral', 'score': 0.9924355149269104}], '688981'),
#  ('我已按计划在89以下满融但还没有满仓相当于不融资股友的半仓中芯向下的空间很',
#   [{'label': 'Neutral', 'score': 0.9978700876235962}],
#   '688981'),
#  ('收盘绝对破88不跑就等待着挨雷吧',
#   [{'label': 'Neutral', 'score': 0.9606720805168152}],
#   '688981'),
#  ('到85元一点问题没有', [{'label': 'Neutral', 'score': 0.9873834252357483}], '688981'),
#  ('垃圾到家了', [{'label': 'Neutral', 'score': 0.9762411713600159}], '688981'),
#  ('今天银行股涨其他股大跌中芯微跌明天银行股跌其他股大涨中芯微跌每天就是',
#   [{'label': 'Neutral', 'score': 0.6322299838066101}],
#   '688981'),
#  ('很有耐心一点一点吐给散户',
#   [{'label': 'Neutral', 'score': 0.9588437080383301}],
#   '688981'),
#  ('好的公司不惧回调越调越买不融资就不会有风险',
#   [{'label': 'Neutral', 'score': 0.9619107246398926}],
#   '688981'),
#  ('别红我80等你', [{'label': 'Neutral', 'score': 0.9852246046066284}], '688981'),
#  ('中哥好稳等我圣哥张完我80等你千万别拉太快',
#   [{'label': 'Neutral', 'score': 0.9847778081893921}],
#   '688981'),
#  ('四月九日我在大盘基本稳定后2113满融满仓备选股宁德时代今天清仓卖出加上',
#   [{'label': 'Neutral', 'score': 0.9966937303543091}],
#   '688981'),
#  ('到85元有点问题没有', [{'label': 'Neutral', 'score': 0.9487888813018799}], '688981'),
#  ('万亿市值的东西几分钱的上下',
#   [{'label': 'Neutral', 'score': 0.9951325058937073}],
#   '688981'),
#  ('能不能涨到200元啊', [{'label': 'Neutral', 'score': 0.9820742011070251}], '688981'),
#  ('快点80我好建仓', [{'label': 'Neutral', 'score': 0.9894225001335144}], '688981'),
#  ('兄弟80几号到', [{'label': 'Neutral', 'score': 0.989587664604187}], '688981'),
#  ('主动权益基金一季度重仓股出炉腾讯跃升至第一阿里比亚迪中芯国际新进前十',
#   [{'label': 'Neutral', 'score': 0.9852679967880249}],
#   '688981'),
#  ('交易清淡主力进入假期模式只留守门员了上午的高点可能不是今天的最高点低点也',
#   [{'label': 'Negative', 'score': 0.5802711248397827}],
#   '688981'),
#  ('空头的力气已经用完了现在只要耐心等待东风来就可以了',
#   [{'label': 'Neutral', 'score': 0.9937334656715393}],
#   '688981'),
#  ('寒武纪值700你中芯只值80吗',
#   [{'label': 'Neutral', 'score': 0.9926704168319702}],
#   '688981'),
#  ('大东尽出这些东西', [{'label': 'Neutral', 'score': 0.990584135055542}], '688981'),
#  ('半导体代工行业属于比较典型的重资产周期性行业估值参考市销率或市净率比PE更客观',
#   [{'label': 'Neutral', 'score': 0.9966320395469666}],
#   '688981'),
#  ('中芯这个股觉得风险评估极大大部分人都一直坚持持有并且越跌越加仓目前是下跌',
#   [{'label': 'Neutral', 'score': 0.9941428303718567}],
#   '688981'),
#  ('没上车的赶紧上车', [{'label': 'Neutral', 'score': 0.9901944994926453}], '688981'),
#  ('下周必将爆跌', [{'label': 'Negative', 'score': 0.5587521195411682}], '688981'),
#  ('周末人工智能高科技芯片出了这么大利好怎么东方财富一个也发不上来',
#   [{'label': 'Positive', 'score': 0.9916022419929504}],
#   '688981'),
#  ('科技股调仓曝光基金经理看多港股',
#   [{'label': 'Neutral', 'score': 0.9935192465782166}],
#   '688981'),
#  ('一路下跌以后这臭股就在50以下震荡直到退市',
#   [{'label': 'Neutral', 'score': 0.7095320224761963}],
#   '688981'),
#  ('中芯国际大宗交易成交269万股 成交额20167万元',
#   [{'label': 'Neutral', 'score': 0.9971357583999634}],
#   '688981'),
#  ('我们的中芯国际就属于暂缓披露信息的公司吗',
#   [{'label': 'Neutral', 'score': 0.9975409507751465}],
#   '688981'),
#  ('雅克这个业绩要感谢国内晶圆厂的持续扩产未来可期',
#   [{'label': 'Neutral', 'score': 0.9557945132255554}],
#   '688981'),
#  ('周末出高科技这么多利好周一科技股要大涨了',
#   [{'label': 'Positive', 'score': 0.9976209998130798}],
#   '688981'),
#  ('看来确实不值钱', [{'label': 'Neutral', 'score': 0.8424188494682312}], '688981'),
#  ('近几日频繁大宗交易是在往下引导股价吗',
#   [{'label': 'Neutral', 'score': 0.9962053894996643}],
#   '688981'),
#  ('操作股票一定要操作自己最熟悉的股票把资金安全放在第一位目前中芯走势不理想喜',
#   [{'label': 'Negative', 'score': 0.9984392523765564}],
#   '688981'),
#  ('市场分歧明显 关注半导体算力自主可控科技主线',
#   [{'label': 'Neutral', 'score': 0.9962735176086426}],
#   '688981'),
#  ('阴跌不止就说明有利空预测一季报有利空不及预期',
#   [{'label': 'Negative', 'score': 0.9259026050567627}],
#   '688981'),
#  ('今年可见150', [{'label': 'Neutral', 'score': 0.9886382222175598}], '688981'),
#  ('3月份十大股东为什么剩3家了呢都跑了吗',
#   [{'label': 'Neutral', 'score': 0.9821161031723022}],
#   '688981'),
#  ('平均持仓成本8334支撑位851量能呈出逃趋势股价得五一后才有行情了',
#   [{'label': 'Neutral', 'score': 0.9954938888549805}],
#   '688981'),
#  ('一季报不是应该4月30号之前披露吗为什么5月9号',
#   [{'label': 'Neutral', 'score': 0.9953190684318542}],
#   '688981'),
#  ('中芯国际本周融资净偿还337372万元居半导体板块第十一',
#   [{'label': 'Neutral', 'score': 0.953719973564148}],
#   '688981'),
#  ('创新高是时间问题', [{'label': 'Neutral', 'score': 0.9648296236991882}], '688981'),
#  ('同样情况下隔夜挂单先成交',
#   [{'label': 'Neutral', 'score': 0.9964550733566284}],
#   '688981'),
#  ('终于等到从他口中说出来重点发展人工智展科技人工智能的话了了可以干活了吧',
#   [{'label': 'Neutral', 'score': 0.985872209072113}],
#   '688981'),
#  ('股吧天天吹股价天天跌为啥呢',
#   [{'label': 'Neutral', 'score': 0.9932143688201904}],
#   '688981'),
#  ('一文不值大家抓紧卖卖卖',
#   [{'label': 'Neutral', 'score': 0.9796725511550903}],
#   '688981'),
#  ('芯片豁免就会减少国产替代进程吗',
#   [{'label': 'Neutral', 'score': 0.9946473240852356}],
#   '688981'),
#  ('铋芯片闪亮登场', [{'label': 'Neutral', 'score': 0.9958025813102722}], '688981'),
#  ('上午的尖底8845是量化砸出来无操作性全天5分K阴线有量阳线无量尖底不保',
#   [{'label': 'Neutral', 'score': 0.9969850182533264}],
#   '688981'),
#  ('88可以买了', [{'label': 'Neutral', 'score': 0.9905555844306946}], '688981'),
#  ('大宗交易中芯国际成交20167万元折价15180425',
#   [{'label': 'Neutral', 'score': 0.997765064239502}],
#   '688981'),
#  ('下周一开始人工智能起来了吧科技技起',
#   [{'label': 'Neutral', 'score': 0.9933233857154846}],
#   '688981'),
#  ('公司的产能利用率是多少', [{'label': 'Neutral', 'score': 0.995375394821167}], '688981'),
#  ('隔夜挂单可以做个决定', [{'label': 'Neutral', 'score': 0.9915688633918762}], '688981'),
#  ('银华基金李晓星看好港股市场以及A股现金流好且估值低位的消费股',
#   [{'label': 'Positive', 'score': 0.9949114918708801}],
#   '688981'),
#  ('光刻机相关设备材料不攻克就看不到发展空间近期股价的发展已说明一切',
#   [{'label': 'Neutral', 'score': 0.996948778629303}],
#   '688981'),
#  ('上市公司用专利积聚核心竞争力',
#   [{'label': 'Neutral', 'score': 0.6272009015083313}],
#   '688981'),
#  ('为什么不打击扰乱市场的内幕交易和所谓大折价的大宗交易',
#   [{'label': 'Neutral', 'score': 0.9968003034591675}],
#   '688981'),
#  ('这只票大概调整到76附近比较适合介入',
#   [{'label': 'Neutral', 'score': 0.9963605999946594}],
#   '688981'),
#  ('中芯国际连续3日融资净偿还累计2亿元0425',
#   [{'label': 'Neutral', 'score': 0.9970924854278564}],
#   '688981'),
#  ('科创板今日大宗交易成交488667万元',
#   [{'label': 'Neutral', 'score': 0.9976623058319092}],
#   '688981'),
#  ('估计要重新回到70多', [{'label': 'Neutral', 'score': 0.9737964868545532}], '688981'),
#  ('主力资金这几天都在拼命大量流出应该是有利空了下周可能直接干到70左右',
#   [{'label': 'Positive', 'score': 0.9555245041847229}],
#   '688981'),
#  ('中芯国际中芯国际2024年度内部控制评价报告',
#   [{'label': 'Neutral', 'score': 0.9971565008163452}],
#   '688981'),
#  ('中芯国际中芯国际2024年度内部控制审计报告',
#   [{'label': 'Neutral', 'score': 0.9973863959312439}],
#   '688981'),
#  ('预测下个星期跌破80再次进入70的平台才可以关注60左右可以进场了',
#   [{'label': 'Neutral', 'score': 0.995907187461853}],
#   '688981'),
#  ('建议主动退市', [{'label': 'Neutral', 'score': 0.9857125282287598}], '688981'),
#  ('请问下最近有机构或者基金等调研公司吗',
#   [{'label': 'Neutral', 'score': 0.9928582906723022}],
#   '688981'),
#  ('公司A股股东户数是多少',
#   [{'label': 'Neutral', 'score': 0.9971725344657898}],
#   '688981'),
#  ('这一堆公告就是今天跌的理由吗',
#   [{'label': 'Neutral', 'score': 0.9812925457954407}],
#   '688981'),
#  ('真心来个跌停', [{'label': 'Neutral', 'score': 0.9700760245323181}], '688981'),
#  ('隔夜挂单是我的第一目标',
#   [{'label': 'Neutral', 'score': 0.9966533780097961}],
#   '688981'),
#  ('我以为是龙头呢谁知道买个垃圾',
#   [{'label': 'Neutral', 'score': 0.9838559627532959}],
#   '688981'),
#  ('尾盘8839卖了折腾不起主力就是想砸盘',
#   [{'label': 'Neutral', 'score': 0.9917271137237549}],
#   '688981'),
#  ('这段时间就是GJD在出货4月7号进的这几天在不计成本的出卖一总是大单在出',
#   [{'label': 'Neutral', 'score': 0.9955348968505859}],
#   '688981'),
#  ('还不抢只能说脑壳里少了东西的',
#   [{'label': 'Neutral', 'score': 0.9566012024879456}],
#   '688981'),
#  ('即将连续爆涨国产替代一号龙头第一目标翻倍第二目标翻十倍赶紧买',
#   [{'label': 'Neutral', 'score': 0.961558997631073}],
#   '688981'),
#  ('出什么事了向下破位了', [{'label': 'Neutral', 'score': 0.9773684740066528}], '688981'),
#  ('臭哎太辣了', [{'label': 'Neutral', 'score': 0.9611645936965942}], '688981'),
#  ('中芯国际发生3笔大宗交易 合计成交75735万元',
#   [{'label': 'Neutral', 'score': 0.9972133040428162}],
#   '688981'),
#  ('静待花开了', [{'label': 'Neutral', 'score': 0.9449653029441833}], '688981'),
#  ('多家公司Q1业绩预喜 上海半导体一季度出现结构性机会',
#   [{'label': 'Positive', 'score': 0.9579054713249207}],
#   '688981'),
#  ('继续加仓中芯国际A股适当减少中芯国际Ｈ股',
#   [{'label': 'Neutral', 'score': 0.997276246547699}],
#   '688981'),
#  ('任凭东南西北风千锤百炼风中行上午继续小赚下午看你反弹',
#   [{'label': 'Neutral', 'score': 0.985898494720459}],
#   '688981'),
#  ('一直有减持的票也敢买', [{'label': 'Neutral', 'score': 0.9921277761459351}], '688981'),
#  ('清仓清场吧受不了了从赢10到亏5',
#   [{'label': 'Neutral', 'score': 0.9923180341720581}],
#   '688981'),
#  ('能回到去年8月份的股价吗不然怎么做好人买好股得好报呢',
#   [{'label': 'Neutral', 'score': 0.9888667464256287}],
#   '688981'),
#  ('差不多了', [{'label': 'Neutral', 'score': 0.9187642335891724}], '688981'),
#  ('大家伙有没发现最近没有新闻报道支持高科技发展了看来科技股没戏了',
#   [{'label': 'Neutral', 'score': 0.9881826043128967}],
#   '688981'),
#  ('外围的半导体全部是在大涨指数都是三倍做多的国内的半导体是玩命的跌天天的阴跌',
#   [{'label': 'Neutral', 'score': 0.9826778769493103}],
#   '688981'),
#  ('大到汽车小智能音箱智能时代万物皆芯片在于时间问题决心因素',
#   [{'label': 'Neutral', 'score': 0.9967817068099976}],
#   '688981'),
#  ('中芯国际5月9日将召开2025年第一季度业绩说明会',
#   [{'label': 'Neutral', 'score': 0.9980236291885376}],
#   '688981'),
#  ('高性能的模拟集成电路和功率器件芯片商业绩王者归来年报095派8元小盘绩优',
#   [{'label': 'Positive', 'score': 0.9967809915542603}],
#   '688981'),
#  ('怎么天天有大宗交易哪位大咖能耐心讲解下',
#   [{'label': 'Neutral', 'score': 0.9960328936576843}],
#   '688981'),
#  ('我从3月24日发长文调整思路后预测准得惊人我目前还是持有某德15个点满融',
#   [{'label': 'Neutral', 'score': 0.9956672191619873}],
#   '688981'),
#  ('大宗交易中芯国际成交75735万元成交均价8910元0424',
#   [{'label': 'Neutral', 'score': 0.9972666501998901}],
#   '688981'),
#  ('拥抱一切的隔夜挂单', [{'label': 'Neutral', 'score': 0.9941746592521667}], '688981'),
#  ('发生啥了很尴尬啊这水跳的直接把上证砸下来啦',
#   [{'label': 'Neutral', 'score': 0.9760077595710754}],
#   '688981'),
#  ('预感明天周五会大跌', [{'label': 'Negative', 'score': 0.961909830570221}], '688981'),
#  ('959套了我2208股这两天分别在9045和8989买入1000补仓还',
#   [{'label': 'Neutral', 'score': 0.9947351813316345}],
#   '688981'),
#  ('业绩这么差高估了10倍',
#   [{'label': 'Negative', 'score': 0.9902175068855286}],
#   '688981'),
#  ('一季度预计收入236亿美元同比增加349环比增长8却连跌4个月',
#   [{'label': 'Positive', 'score': 0.9982216954231262}],
#   '688981'),
#  ('全面拥抱科技股 公募基金含科量成风向标',
#   [{'label': 'Neutral', 'score': 0.9971849322319031}],
#   '688981'),
#  ('中芯国际中芯国际关于召开2025年第一季度业绩说明会的预告公告',
#   [{'label': 'Neutral', 'score': 0.9974918365478516}],
#   '688981'),
#  ('董秘出来说句话回答问题呀再不回答就下课吧',
#   [{'label': 'Neutral', 'score': 0.9898734092712402}],
#   '688981'),
#  ('港股一季度迎千亿资金抢筹 科技与消费板块成配置核心',
#   [{'label': 'Neutral', 'score': 0.9975482821464539}],
#   '688981'),
#  ('台积电南京投资基本稳定后一个厂一年就盈利58亿人民币等中芯国际过了扩张期3个',
#   [{'label': 'Neutral', 'score': 0.9783559441566467}],
#   '688981'),
#  ('怀疑这个股未涨过', [{'label': 'Neutral', 'score': 0.9855253100395203}], '688981'),
#  ('每天大宗交易平价成交什么意思',
#   [{'label': 'Neutral', 'score': 0.9964033365249634}],
#   '688981'),
#  ('公募基金2025年一季报数据榜单出炉',
#   [{'label': 'Neutral', 'score': 0.9968365430831909}],
#   '688981'),
#  ('加仓的好时机啊随时可能拉涨的大家赶紧买',
#   [{'label': 'Neutral', 'score': 0.93440181016922}],
#   '688981'),
#  ('下周开启暴涨模式大家拿住有钱就加仓',
#   [{'label': 'Neutral', 'score': 0.9848995208740234}],
#   '688981'),
#  ('前冠军基金一季度调仓大曝光有人积极调仓有人已遭遇业绩滑铁卢',
#   [{'label': 'Negative', 'score': 0.9180288314819336}],
#   '688981'),
#  ('AS中芯未来难测未来10年业绩大增雅砻江水电',
#   [{'label': 'Positive', 'score': 0.9897854924201965}],
#   '688981'),
#  ('中芯国际大宗交易成交39317万元',
#   [{'label': 'Neutral', 'score': 0.9978491067886353}],
#   '688981'),
#  ('24股4月22日获杠杆资金加仓超5000万元',
#   [{'label': 'Neutral', 'score': 0.99713134765625}],
#   '688981'),
#  ('七十万追五涨停四川电力600644牛哦四川水电',
#   [{'label': 'Neutral', 'score': 0.994902491569519}],
#   '688981'),
#  ('大宗交易机构账户买入中芯国际39317万元0423',
#   [{'label': 'Neutral', 'score': 0.9930976033210754}],
#   '688981'),
#  ('超越宁德和茅台 港股腾讯首次成为公募基金第一重仓股',
#   [{'label': 'Neutral', 'score': 0.9876118302345276}],
#   '688981'),
#  ('90以上都是泡沫80以下可以关注60以下可以进场40可以全仓',
#   [{'label': 'Neutral', 'score': 0.9975155591964722}],
#   '688981'),
#  ('又完了', [{'label': 'Neutral', 'score': 0.9450189471244812}], '688981'),
#  ('5个行业获融资净买入超1亿元 5股获融资净买入额超1亿元',
#   [{'label': 'Neutral', 'score': 0.5164604187011719}],
#   '688981'),
#  ('为啥这个股吧有那么多其它垃圾股的资讯或广告啊',
#   [{'label': 'Neutral', 'score': 0.969135582447052}],
#   '688981'),
#  ('1隔夜挂单是时间的朋友越久越见真章',
#   [{'label': 'Neutral', 'score': 0.9945218563079834}],
#   '688981'),
#  ('5只科创板股今日大宗交易平台发生交易',
#   [{'label': 'Neutral', 'score': 0.9978377223014832}],
#   '688981'),
#  ('咱不行别做芯片了做餐饮吧看东哥都去你家接单了做芯片太委屈你了',
#   [{'label': 'Neutral', 'score': 0.9806727766990662}],
#   '688981'),
#  ('加仓猛干今年上200', [{'label': 'Neutral', 'score': 0.9761880040168762}], '688981'),
#  ('十年磨一剑七剑才刚刚下天山现在刚刚是第一把剑的第6年',
#   [{'label': 'Neutral', 'score': 0.9969134330749512}],
#   '688981'),
#  ('僵尸', [{'label': 'Neutral', 'score': 0.968434751033783}], '688981'),
#  ('公募基金一季报收官主动权益类基金盈利近五年同期最优',
#   [{'label': 'Positive', 'score': 0.9985085129737854}],
#   '688981'),
#  ('为什么中芯国际和华虹公司每年产能逐步增加净利润却逐步减少',
#   [{'label': 'Negative', 'score': 0.7457531094551086}],
#   '688981'),
#  ('半个月后来看一下就好了这个是木头不动了',
#   [{'label': 'Neutral', 'score': 0.9879662394523621}],
#   '688981'),
#  ('美那边芯片法案要落地这可能要加快国产替代进程我准备低位搞点半导体ETFS',
#   [{'label': 'Neutral', 'score': 0.9969583749771118}],
#   '688981'),
#  ('每天都亏的很稳定', [{'label': 'Neutral', 'score': 0.9518305063247681}], '688981'),
#  ('可以护盘一波了哈', [{'label': 'Neutral', 'score': 0.9859094023704529}], '688981'),
#  ('五日线都站不上去简直贻笑大方',
#   [{'label': 'Neutral', 'score': 0.9388467669487}],
#   '688981'),
#  ('沦落成僵尸股了', [{'label': 'Neutral', 'score': 0.9799444675445557}], '688981'),
#  ('', [{'label': 'Neutral', 'score': 0.9767643809318542}], '688981'),
#  ('太臭了久久买一次就把我套住9045',
#   [{'label': 'Neutral', 'score': 0.9786699414253235}],
#   '688981'),
#  ('卖单全是222222的是不是机构出货',
#   [{'label': 'Neutral', 'score': 0.9964151382446289}],
#   '688981'),
#  ('看这块八毛的给你累的', [{'label': 'Neutral', 'score': 0.8141449093818665}], '688981'),
#  ('赶紧绿大春活', [{'label': 'Neutral', 'score': 0.9829657673835754}], '688981'),
#  ('太臭了量化天天几毛钱做差',
#   [{'label': 'Neutral', 'score': 0.9809538125991821}],
#   '688981'),
#  ('YY一下随时准备拉起来本周必有大阳线',
#   [{'label': 'Neutral', 'score': 0.9851049780845642}],
#   '688981'),
#  ('大盘3338的时候你105现在大盘3300你90我104的本啊Kao',
#   [{'label': 'Neutral', 'score': 0.994106650352478}],
#   '688981'),
#  ('是想等着明天港股来了一起涨',
#   [{'label': 'Neutral', 'score': 0.9935310482978821}],
#   '688981'),
#  ('自主可控明确替代空间如何捕捉投资新机遇',
#   [{'label': 'Neutral', 'score': 0.989231288433075}],
#   '688981'),
#  ('大幅加仓美的茅台买入小米 银华基金李晓星看好港股与A股消费股',
#   [{'label': 'Positive', 'score': 0.9164369106292725}],
#   '688981'),
#  ('给点力兄弟带领板块冲一下',
#   [{'label': 'Neutral', 'score': 0.9930720925331116}],
#   '688981'),
#  ('去年四季度加仓信立泰华海药业中欧基金葛兰科技创新消费复苏是核心关注方向',
#   [{'label': 'Neutral', 'score': 0.9976167678833008}],
#   '688981'),
#  ('中芯虐我千百遍我却待它如初恋与它相处三年半股性吃相最难看短线这里挣快钱',
#   [{'label': 'Neutral', 'score': 0.9922147393226624}],
#   '688981'),
#  ('最新公募基金前十大重仓股出炉',
#   [{'label': 'Neutral', 'score': 0.997238039970398}],
#   '688981'),
#  ('兴全明星基金经理调仓曝光',
#   [{'label': 'Neutral', 'score': 0.997539758682251}],
#   '688981'),
#  ('这次调整应该要跌破77去60吧半导体里海光中微华创等龙头都是上升趋势只有',
#   [{'label': 'Neutral', 'score': 0.9915466904640198}],
#   '688981'),
#  ('腾讯登顶公募十大重仓股出炉',
#   [{'label': 'Neutral', 'score': 0.9966369867324829}],
#   '688981'),
#  ('中芯国际买不到先进光刻机否则早没台积电什么事了',
#   [{'label': 'Neutral', 'score': 0.9972412586212158}],
#   '688981'),
#  ('距离年底8个月维持300的目标价不变每天开盘暴击不过是小孩子的把戏回头看去',
#   [{'label': 'Neutral', 'score': 0.9951059818267822}],
#   '688981'),
#  ('中芯国际sh688981',
#   [{'label': 'Neutral', 'score': 0.9971765279769897}],
#   '688981'),
#  ('科创板的罪人', [{'label': 'Neutral', 'score': 0.9800713658332825}], '688981'),
#  ('下半年业绩暴增', [{'label': 'Positive', 'score': 0.9989582300186157}], '688981'),
#  ('还没到买入的时机需要等很长时间',
#   [{'label': 'Neutral', 'score': 0.9885879755020142}],
#   '688981'),
#  ('大宗交易中芯国际成交55807万元成交均价9001元0422',
#   [{'label': 'Neutral', 'score': 0.9972088932991028}],
#   '688981'),
#  ('台积电在大陆竟然盈利260亿新台币58亿人民币他们可是生产的成熟制程芯片在',
#   [{'label': 'Neutral', 'score': 0.9971467852592468}],
#   '688981'),
#  ('先看调整到年线70再看调整到64再不行就回去40砸盘龙头有砸盘龙头自己的走',
#   [{'label': 'Neutral', 'score': 0.9968908429145813}],
#   '688981'),
#  ('操盘手怎么不说话了', [{'label': 'Neutral', 'score': 0.9756053686141968}], '688981'),
#  ('中芯国际现2笔大宗交易 合计成交620万股',
#   [{'label': 'Neutral', 'score': 0.9973681569099426}],
#   '688981'),
#  ('中国AI 50概念下跌209主力资金净流出44股',
#   [{'label': 'Negative', 'score': 0.9941006302833557}],
#   '688981'),
#  ('50左右就是好股票现在90了就是泡沫股了好和坏和公司无关和股价相关',
#   [{'label': 'Neutral', 'score': 0.9967125654220581}],
#   '688981'),
#  ('港股卖空单7177万股占当日流通803这何方大佬看空中芯了',
#   [{'label': 'Neutral', 'score': 0.9947346448898315}],
#   '688981'),
#  ('几乎没有现金分红的股票就是庞氏骗局股价就是靠后来傻瓜不断烧钱堆高最后一地鸡毛',
#   [{'label': 'Neutral', 'score': 0.9933717250823975}],
#   '688981'),
#  ('抱歉了各位怨我全仓买入该票所以一直调整我就是股票晴雨表请大家反向操作',
#   [{'label': 'Neutral', 'score': 0.9972122311592102}],
#   '688981'),
#  ('时隔近四年 大基金再度减持中芯国际',
#   [{'label': 'Neutral', 'score': 0.9970490336418152}],
#   '688981'),
#  ('公告精选丨中芯国际鑫芯香港3月28日减持1130万股公司港股持股降至691北方华创拟1448亿元协议受让芯源微841股份',
#   [{'label': 'Neutral', 'score': 0.9971919655799866}],
#   '688981'),
#  ('今年以来南下资金净买入突破6000亿港元 已超去年全年净买入额七成',
#   [{'label': 'Positive', 'score': 0.9955322742462158}],
#   '688981'),
#  ('我为散户发声赶紧买不要下车',
#   [{'label': 'Neutral', 'score': 0.9933276176452637}],
#   '688981'),
#  ('中芯国际已经是机构控制的公司了散户激不起任何波浪',
#   [{'label': 'Neutral', 'score': 0.99625563621521}],
#   '688981'),
#  ('未来芯片还得靠寒武纪', [{'label': 'Neutral', 'score': 0.9929981231689453}], '688981'),
#  ('垃圾啊我100的本', [{'label': 'Neutral', 'score': 0.9693595767021179}], '688981'),
#  ('最顶级的美光科技市值都没你高啊这泡沫真大',
#   [{'label': 'Neutral', 'score': 0.9318889379501343}],
#   '688981'),
#  ('如如不动', [{'label': 'Neutral', 'score': 0.9884775280952454}], '688981'),
#  ('涨跌随意陪你玩', [{'label': 'Neutral', 'score': 0.9907026290893555}], '688981'),
#  ('加油不管别人怎么说坚定持有中国芯',
#   [{'label': 'Neutral', 'score': 0.9951826930046082}],
#   '688981'),
#  ('海光明天要涨的你乖乖跌就完事了',
#   [{'label': 'Neutral', 'score': 0.9866138100624084}],
#   '688981'),
#  ('短线这次要破了80再考虑进场',
#   [{'label': 'Neutral', 'score': 0.9958733916282654}],
#   '688981'),
#  ('有一些人吹嘘这是两市总龙头吸引了一大批韭菜进来搞的这只股票成了散户大本营和韭',
#   [{'label': 'Neutral', 'score': 0.9971465468406677}],
#   '688981'),
#  ('莫灰心交易对于普通散户来说就是等待',
#   [{'label': 'Neutral', 'score': 0.9892891645431519}],
#   '688981'),
#  ('这K线画的连自己都不信看着都难受',
#   [{'label': 'Neutral', 'score': 0.9210392236709595}],
#   '688981'),
#  ('明天会不会补涨', [{'label': 'Neutral', 'score': 0.9828712940216064}], '688981'),
#  ('中芯国际深度研究报告晶圆制造龙头领航国产芯片新征程',
#   [{'label': 'Neutral', 'score': 0.9958819150924683}],
#   '688981'),
#  ('无论中美关税谈判如何国产替代将是强国的大方针也是基础方针中芯国际是国产替代的',
#   [{'label': 'Neutral', 'score': 0.9977695941925049}],
#   '688981'),
#  ('后关税时代对内看大消费对外看半导体双主线拿稳了',
#   [{'label': 'Neutral', 'score': 0.8684251308441162}],
#   '688981'),
#  ('中芯国际的垃圾丢人的板块里谁不比你强',
#   [{'label': 'Neutral', 'score': 0.9742364883422852}],
#   '688981'),
#  ('又到大家开骂中芯垃圾的一天',
#   [{'label': 'Neutral', 'score': 0.9851344227790833}],
#   '688981'),
#  ('最近半导体算是走的最稳的方向了资金流入也比其他好我主要冲国产替代这条线半',
#   [{'label': 'Positive', 'score': 0.9777357578277588}],
#   '688981'),
#  ('大盘今天强势不需要护盘了',
#   [{'label': 'Positive', 'score': 0.9264824986457825}],
#   '688981'),
#  ('10连阳了防守为主', [{'label': 'Neutral', 'score': 0.9962449669837952}], '688981'),
#  ('板块都被你带崩', [{'label': 'Neutral', 'score': 0.9845089316368103}], '688981'),
#  ('自主可控就你这样', [{'label': 'Neutral', 'score': 0.9929391145706177}], '688981'),
#  ('老', [{'label': 'Neutral', 'score': 0.9691129922866821}], '688981'),
#  ('中芯国际股份奖励计划共授出288万限制性股票',
#   [{'label': 'Neutral', 'score': 0.9972188472747803}],
#   '688981'),
#  ('盲猜中芯下一目标位176',
#   [{'label': 'Neutral', 'score': 0.9832912683486938}],
#   '688981'),
#  ('预测非常准确大家看看我文中的观点到目前为止全对我还是持有某德还在上涨中',
#   [{'label': 'Positive', 'score': 0.9522532224655151}],
#   '688981'),
#  ('全球40份额被美国逼出来的中国半导体正上演逆袭奇迹',
#   [{'label': 'Neutral', 'score': 0.5113953351974487}],
#   '688981'),
#  ('盘子大难以大涨大跌', [{'label': 'Neutral', 'score': 0.7721060514450073}], '688981'),
#  ('我咋有种海光信息要起飞的感觉我只是看看没买哈同一个板块都是大体量看看怎',
#   [{'label': 'Neutral', 'score': 0.9948634505271912}],
#   '688981'),
#  ('耐心', [{'label': 'Neutral', 'score': 0.9569107890129089}], '688981'),
#  ('供应中芯国际海力士美光三星的国产替代芯片制造材料被疯狂做空中大家来抄底',
#   [{'label': 'Neutral', 'score': 0.9970802664756775}],
#   '688981'),
#  ('豆包说你当前股价35元我刚刚问的实际上你都90多了咋办',
#   [{'label': 'Neutral', 'score': 0.9902271032333374}],
#   '688981'),
#  ('你懂啥没吃到葡萄说葡萄酸',
#   [{'label': 'Neutral', 'score': 0.9859212040901184}],
#   '688981'),
#  ('现在散户的筹码都被主力收走了那天横空出世特大利好拉个涨停板你就彻底踏空了',
#   [{'label': 'Neutral', 'score': 0.9710006713867188}],
#   '688981'),
#  ('这股长期持有肯定是没有问题的等中芯攻克7nm跟5nm就行了攻克只是时间问题',
#   [{'label': 'Neutral', 'score': 0.9979438185691833}],
#   '688981'),
#  ('看好这一方向 基金经理港股调仓思路曝光',
#   [{'label': 'Positive', 'score': 0.9393790364265442}],
#   '688981'),
#  ('老弟来了', [{'label': 'Neutral', 'score': 0.978398323059082}], '688981'),
#  ('中芯国际是情怀票需要有长期主义不离不弃的精神才能持有它这个月不涨下个月不',
#   [{'label': 'Neutral', 'score': 0.9967408776283264}],
#   '688981'),
#  ('老夫认为中芯国际可以在三季度拉一拉但幅度不会太大也可以就这么震荡到年底都是',
#   [{'label': 'Neutral', 'score': 0.9972743391990662}],
#   '688981'),
#  ('重磅中芯国际为寒武纪代工AI芯片即将开启连续涨停',
#   [{'label': 'Positive', 'score': 0.9970878958702087}],
#   '688981'),
#  ('多股获机构看好目标涨幅最大4686213',
#   [{'label': 'Positive', 'score': 0.9980668425559998}],
#   '688981'),
#  ('中芯国际本周融资净偿还93289万元居半导体板块第四',
#   [{'label': 'Neutral', 'score': 0.8648563027381897}],
#   '688981'),
#  ('黄总找中芯代工是真是假',
#   [{'label': 'Neutral', 'score': 0.9880118370056152}],
#   '688981'),
#  ('喷寒武纪连年亏损还炒那么高的闭嘴了',
#   [{'label': 'Neutral', 'score': 0.9647519588470459}],
#   '688981'),
#  ('寒武纪有问题芯片行业持续亏钱你会好到哪里去',
#   [{'label': 'Negative', 'score': 0.9903533458709717}],
#   '688981'),
#  ('黄仁勋来大陆和郑文锋协商研发高科技AI芯片中芯国际代工中芯国际应该会有较大的',
#   [{'label': 'Neutral', 'score': 0.9979925155639648}],
#   '688981'),
#  ('专利申请4月19日消息国家知识产权局信息显示中芯国际集成电路制造北京',
#   [{'label': 'Neutral', 'score': 0.9974563717842102}],
#   '688981'),
#  ('寒武纪今年一季报更是惊人公司实现总营收1111亿元几乎相当于2024年全年',
#   [{'label': 'Neutral', 'score': 0.9728299975395203}],
#   '688981'),
#  ('市场需要好的芯片消费需要芯片',
#   [{'label': 'Neutral', 'score': 0.9959986209869385}],
#   '688981'),
#  ('A中芯不会大涨也不会大跌放心持有长线看好',
#   [{'label': 'Positive', 'score': 0.9978919625282288}],
#   '688981'),
#  ('观棋不语', [{'label': 'Neutral', 'score': 0.9737192392349243}], '688981'),
#  ('未来不可预测', [{'label': 'Neutral', 'score': 0.903965175151825}], '688981'),
#  ('百元票', [{'label': 'Neutral', 'score': 0.9910393357276917}], '688981'),
#  ('除非台积电的14nm以下芯片恢复对大陆市场的供应中芯国际永远是不可替代的由于',
#   [{'label': 'Neutral', 'score': 0.9974679946899414}],
#   '688981'),
#  ('中芯国际泡沫尤其大上市之日创出95高点后便走上了去泡沫之路这一走就是5年这5年公',
#   [{'label': 'Neutral', 'score': 0.9974060654640198}],
#   '688981'),
#  ('能不能涨10让我减仓200股',
#   [{'label': 'Neutral', 'score': 0.9937268495559692}],
#   '688981'),
#  ('寒武纪一季报扭亏为盈营收火箭式增长了不起这货可能微利或稍有下降中芯只是名号大些',
#   [{'label': 'Positive', 'score': 0.9931685924530029}],
#   '688981'),
#  ('这么多人说到阿寒你们去吧2800亿市值25亿利润你们去吧我坚守中芯和胜宏了',
#   [{'label': 'Neutral', 'score': 0.996590256690979}],
#   '688981'),
#  ('一季度报基本可以确定老寒AI龙头地位了看万亿市值没啥犹豫的了',
#   [{'label': 'Neutral', 'score': 0.9960476756095886}],
#   '688981'),
#  ('中芯国际融资净偿还247212万元融资余额7281亿元0418',
#   [{'label': 'Neutral', 'score': 0.9974344372749329}],
#   '688981'),
#  ('过来寒武纪才是你们唯一的出路',
#   [{'label': 'Neutral', 'score': 0.9946762323379517}],
#   '688981'),
#  ('有机会和英伟达合作吗', [{'label': 'Neutral', 'score': 0.9934731125831604}], '688981'),
#  ('周一寒王能带动你么', [{'label': 'Neutral', 'score': 0.9869968891143799}], '688981'),
#  ('去上海了自己想意味着什么',
#   [{'label': 'Neutral', 'score': 0.9928975105285645}],
#   '688981'),
#  ('梁跃军最新调仓曝光', [{'label': 'Neutral', 'score': 0.9971863627433777}], '688981'),
#  ('百亿天团壮大 创新引领半导体产业崛起',
#   [{'label': 'Neutral', 'score': 0.8147435188293457}],
#   '688981'),
#  ('难道要给英伟达代工了', [{'label': 'Neutral', 'score': 0.9927384257316589}], '688981'),
#  ('寒王大利好兑现涨幅太多怎么走不确定真正大利好的是中芯是可以确定的',
#   [{'label': 'Positive', 'score': 0.962274968624115}],
#   '688981'),
#  ('H20中芯国际代工', [{'label': 'Neutral', 'score': 0.9964738488197327}], '688981'),
#  ('都是什么人在砸盘', [{'label': 'Neutral', 'score': 0.9762247800827026}], '688981'),
#  ('流动性都去哪了这是主力消极怠工还是在憋大招',
#   [{'label': 'Neutral', 'score': 0.9832950234413147}],
#   '688981'),
#  ('醒一醒你可是龙头啊缩量这么严重',
#   [{'label': 'Negative', 'score': 0.7957367897033691}],
#   '688981'),
#  ('当前行情在85107箱体内震荡整体是看涨目前股价打到箱体的中价线9458',
#   [{'label': 'Positive', 'score': 0.997282862663269}],
#   '688981'),
#  ('突发利好英伟达NVDA表示美国政府出于国家安全原因禁止其向中国销售H20',
#   [{'label': 'Positive', 'score': 0.9959267377853394}],
#   '688981'),
#  ('收盘92块钱不信来看', [{'label': 'Neutral', 'score': 0.9915560483932495}], '688981'),
#  ('最后时刻给你打回原形', [{'label': 'Neutral', 'score': 0.9762576222419739}], '688981'),
#  ('事后诸葛亮清仓中芯买各种微做个短线也不错哈奈何自己买那个能力啊',
#   [{'label': 'Neutral', 'score': 0.9436559677124023}],
#   '688981'),
#  ('指数不想九连阳前面怕成交量不够集体拉了一波后来发现大盘又要红成交量上去',
#   [{'label': 'Positive', 'score': 0.9179502725601196}],
#   '688981'),
#  ('昨天抖音刷到好几个都是吹他要帮黄老板代工的天天吹',
#   [{'label': 'Neutral', 'score': 0.9934656023979187}],
#   '688981'),
#  ('最后一分钟一千股弄着玩玩的还真成交了',
#   [{'label': 'Neutral', 'score': 0.99310702085495}],
#   '688981'),
#  ('阿芯加油', [{'label': 'Neutral', 'score': 0.9676235318183899}], '688981'),
#  ('尾盘集合竞价砸一下什么意思',
#   [{'label': 'Neutral', 'score': 0.995526134967804}],
#   '688981'),
#  ('美帝那边要豁免半导体预期还在这政策风向一转政策红利加持国产替代加速半导',
#   [{'label': 'Neutral', 'score': 0.9703710079193115}],
#   '688981'),
#  ('英伟达联合Deepseek在中国研制AI芯片并在中芯国际流片制程知识产权本地化',
#   [{'label': 'Neutral', 'score': 0.9974563717842102}],
#   '688981'),
#  ('国产替代自主可控势在必行技术一有突破立马质变腾飞',
#   [{'label': 'Neutral', 'score': 0.9937148690223694}],
#   '688981'),
#  ('芯片是未来大有潜力的行业目前主力在吸筹尾盘拉一下盘中下跌走势还没有到发',
#   [{'label': 'Positive', 'score': 0.9879652261734009}],
#   '688981'),
#  ('业绩才是硬道理', [{'label': 'Neutral', 'score': 0.9800670146942139}], '688981'),
#  ('跌下来吧不用在90块上面死死扛着洗洗更健康后面才好涨',
#   [{'label': 'Neutral', 'score': 0.9443358182907104}],
#   '688981'),
#  ('台积电营收增长百分之四十利润同比增长百分之六十中芯国际不会差等待爆发',
#   [{'label': 'Positive', 'score': 0.9978367686271667}],
#   '688981'),
#  ('英伟达要利用中芯国际现有产能生产H20',
#   [{'label': 'Neutral', 'score': 0.9982473850250244}],
#   '688981'),
#  ('拉尾盘明天死趐', [{'label': 'Neutral', 'score': 0.9879515767097473}], '688981'),
#  ('有没有一种可能是中芯国际代工英伟达H20美国受限了我们这边可以做啊也就是黄',
#   [{'label': 'Neutral', 'score': 0.9979926347732544}],
#   '688981'),
#  ('一群低智商开始引意做梦发财了',
#   [{'label': 'Neutral', 'score': 0.9604038596153259}],
#   '688981'),
#  ('中芯国际代工英伟达是最好的解决方案',
#   [{'label': 'Neutral', 'score': 0.554951548576355}],
#   '688981'),
#  ('今天英伟达黄仁勋访华了',
#   [{'label': 'Neutral', 'score': 0.9971944093704224}],
#   '688981'),
#  ('英伟达H20出口受限老黄此时来华目的就是协商破局之策',
#   [{'label': 'Neutral', 'score': 0.9969640374183655}],
#   '688981'),
#  ('明天是否可以下跌让我买一点低价筹码呀',
#   [{'label': 'Neutral', 'score': 0.9903268218040466}],
#   '688981'),
#  ('看看寒武纪再看看你', [{'label': 'Neutral', 'score': 0.9802250266075134}], '688981'),
#  ('778还会去', [{'label': 'Neutral', 'score': 0.9847517609596252}], '688981'),
#  ('隔夜挂单不是押注是用前半夜的清醒锁定后半夜的潜在机遇',
#   [{'label': 'Neutral', 'score': 0.9975398778915405}],
#   '688981'),
#  ('尾盘突发多只高位股跌停',
#   [{'label': 'Negative', 'score': 0.9637911915779114}],
#   '688981'),
#  ('坚持每天尾盘护盘效果很好',
#   [{'label': 'Positive', 'score': 0.9964489936828613}],
#   '688981'),
#  ('完了', [{'label': 'Neutral', 'score': 0.9638199806213379}], '688981'),
#  ('最好的解决方案还是晚上8点的隔夜挂单了',
#   [{'label': 'Neutral', 'score': 0.9863704442977905}],
#   '688981'),
#  ('每天最后一秒拉', [{'label': 'Neutral', 'score': 0.9850045442581177}], '688981'),
#  ('调查显示散户越跌越买也成A股稳定器',
#   [{'label': 'Neutral', 'score': 0.9743228554725647}],
#   '688981'),
#  ('尿性', [{'label': 'Neutral', 'score': 0.9824313521385193}], '688981'),
#  ('92红盘没卖910卖出了8985买入不后悔破91是我的底线',
#   [{'label': 'Neutral', 'score': 0.9961835741996765}],
#   '688981'),
#  ('怪不得半导体都在跳水俩龙头一直趴窝子什么时候你跟华子领先涨什么时候半导体回来',
#   [{'label': 'Neutral', 'score': 0.9919514656066895}],
#   '688981'),
#  ('明日期指交割变盘仍然看涨',
#   [{'label': 'Positive', 'score': 0.9965003728866577}],
#   '688981'),
#  ('彻底完了', [{'label': 'Neutral', 'score': 0.9350670576095581}], '688981'),
#  ('看看你寒爷', [{'label': 'Neutral', 'score': 0.9614559412002563}], '688981'),
#  ('连续尾盘这么干不会憋个大的坏吧',
#   [{'label': 'Neutral', 'score': 0.9182007908821106}],
#   '688981'),
#  ('每天尾盘中金护一下盘主力每天就从头跑到尾',
#   [{'label': 'Neutral', 'score': 0.9966142773628235}],
#   '688981'),
#  ('霉股一只', [{'label': 'Neutral', 'score': 0.9924629926681519}], '688981'),
#  ('你是真弱看看港股你天天跌',
#   [{'label': 'Neutral', 'score': 0.9815461039543152}],
#   '688981'),
#  ('大哥你和华子都是半导体龙头哇加油看好你们',
#   [{'label': 'Positive', 'score': 0.9947336912155151}],
#   '688981'),
#  ('中芯国际大宗交易成交220万股 成交额20240万元',
#   [{'label': 'Neutral', 'score': 0.997349739074707}],
#   '688981'),
#  ('中芯国际鑫芯香港3月28日减持1130万股公司港股 持股降至691',
#   [{'label': 'Neutral', 'score': 0.997617781162262}],
#   '688981'),
#  ('天天国产替代也就是画画饼讲讲故事能替代早就替代了还需要说吗中芯主要就是',
#   [{'label': 'Neutral', 'score': 0.9972622394561768}],
#   '688981'),
#  ('美芯片股受许可证影响大跌国产替代起飞',
#   [{'label': 'Negative', 'score': 0.8184171319007874}],
#   '688981'),
#  ('还有比4月7日的突发消息更有杀伤力的吗',
#   [{'label': 'Neutral', 'score': 0.9647828936576843}],
#   '688981'),
#  ('中芯已成为调整指数的工具如果不是尾盘ETF硬拉正常位置在89如不护盘有补',
#   [{'label': 'Neutral', 'score': 0.9953489899635315}],
#   '688981'),
#  ('明天要大涨了', [{'label': 'Positive', 'score': 0.9917196035385132}], '688981'),
#  ('6月120', [{'label': 'Neutral', 'score': 0.9659161567687988}], '688981'),
#  ('尾盘某队很用力明天怎么办',
#   [{'label': 'Neutral', 'score': 0.9806628823280334}],
#   '688981'),
#  ('隔夜挂单是什么样的', [{'label': 'Neutral', 'score': 0.9958441853523254}], '688981'),
#  ('914卖了默默地流下了眼泪',
#   [{'label': 'Neutral', 'score': 0.9864360690116882}],
#   '688981'),
#  ('科创板今日大宗交易成交736039万元',
#   [{'label': 'Neutral', 'score': 0.9977018237113953}],
#   '688981'),
#  ('明天科技和金融该修复一下了吧',
#   [{'label': 'Neutral', 'score': 0.9917534589767456}],
#   '688981'),
#  ('尾盘拉升看来明天要大涨了',
#   [{'label': 'Positive', 'score': 0.9988528490066528}],
#   '688981'),
#  ('虽然32503320点的技术性缺口在实战层面表现平平但其作为价格缓冲带的存在',
#   [{'label': 'Neutral', 'score': 0.9971812963485718}],
#   '688981'),
#  ('年报行情要来了最近陆续披露的业绩都不错啊半导体ETF159813应该会有戏可',
#   [{'label': 'Positive', 'score': 0.9979689717292786}],
#   '688981'),
#  ('今天半导体ETFSZ159813逆势上涨太惊喜了我新低时上车当时就',
#   [{'label': 'Positive', 'score': 0.9962353110313416}],
#   '688981'),
#  ('坚定不移地操控中芯国际之决心不动摇你们呀芝麻西瓜黄金黑铁',
#   [{'label': 'Neutral', 'score': 0.9943207502365112}],
#   '688981'),
#  ('按照正常逻辑上周一77下影线最低点应该会破的拭目以待现在仅仅是反抽而已',
#   [{'label': 'Neutral', 'score': 0.9944392442703247}],
#   '688981'),
#  ('有人操纵尾盘啊', [{'label': 'Neutral', 'score': 0.9869452118873596}], '688981'),
#  ('消息轮冒烟耐住性子紧紧抓住这三大半导体主升逻辑',
#   [{'label': 'Neutral', 'score': 0.9960379600524902}],
#   '688981'),
#  ('今天没人说港股了昨天那一堆叫的呢',
#   [{'label': 'Neutral', 'score': 0.9849321246147156}],
#   '688981'),
#  ('大宗交易中芯国际成交2024万元成交价9200元0416',
#   [{'label': 'Neutral', 'score': 0.9972767233848572}],
#   '688981'),
#  ('云飞扬', [{'label': 'Neutral', 'score': 0.987076461315155}], '688981'),
#  ('这尾盘拉的漂亮', [{'label': 'Neutral', 'score': 0.923349916934967}], '688981'),
#  ('关税豁免全球科技博弈正式进入中国时间',
#   [{'label': 'Neutral', 'score': 0.9963523149490356}],
#   '688981'),
#  ('风浪越大鱼越贵', [{'label': 'Neutral', 'score': 0.9870216250419617}], '688981'),
#  ('今天账户就半导体ETFSZ159813这一个红的鼓掌还是挺抗跌的业',
#   [{'label': 'Positive', 'score': 0.589756190776825}],
#   '688981'),
#  ('今天账户就半导体ETF159813这一个红的鼓掌还是挺抗跌的业绩复苏周期',
#   [{'label': 'Neutral', 'score': 0.9743233919143677}],
#   '688981'),
#  ('屏蔽满天飞的利空利多信息按自己理解的节奏做上午10点过后盘口有个底部结构9',
#   [{'label': 'Neutral', 'score': 0.9976319074630737}],
#   '688981'),
#  ('趋势为王现在中芯趋势转强适合做多',
#   [{'label': 'Neutral', 'score': 0.9922296404838562}],
#   '688981'),
#  ('目前4层仓90以下分批吸长期看好',
#   [{'label': 'Positive', 'score': 0.9982927441596985}],
#   '688981'),
#  ('第一技术上这种图形就是开始上升趋势的信号注意120小时均线第二每次回调',
#   [{'label': 'Neutral', 'score': 0.9964784979820251}],
#   '688981'),
#  ('两百倍市盈率看大聪明怎么收尾',
#   [{'label': 'Neutral', 'score': 0.9926250576972961}],
#   '688981'),
#  ('国内最喜欢卷只要这个东西技术放开了马上失去利润半导体将来不知道会卷出什么新花',
#   [{'label': 'Neutral', 'score': 0.97633957862854}],
#   '688981'),
#  ('港股今天跌了十几个点吓人',
#   [{'label': 'Negative', 'score': 0.9854506254196167}],
#   '688981'),
#  ('中芯国际今年大概率亏损',
#   [{'label': 'Negative', 'score': 0.9982513785362244}],
#   '688981'),
#  ('类平准基金应该引领科技股上涨打爆空头至少营造一个牛市氛围半死不活的搞得大',
#   [{'label': 'Neutral', 'score': 0.9913001656532288}],
#   '688981'),
#  ('中芯国际目前比全球其他任何一家芯片厂的发展更具有优势1使用新的算法外国高级',
#   [{'label': 'Positive', 'score': 0.9515396356582642}],
#   '688981'),
#  ('5月9号一季度业绩发布股价破100立此为证静待花开现在波动均可忽略',
# ...
#   '000524'),
#  ('现在又有托开始活动了说章盟主来了看来还得继续跌',
#   [{'label': 'Neutral', 'score': 0.9783880114555359}],
#   '000524'),
#  ('今日尾盘低空经济发力这货没跟上明天会补涨吗',
#   [{'label': 'Positive', 'score': 0.9640722870826721}],
#   '000524'),
#  ('尾盘低空起来都带不起你幸亏昨天走了',
#   [{'label': 'Neutral', 'score': 0.9627150297164917}],
#   '000524'),
#  ('只要我买入的股票不赚10个点我是不会出去的准备迎接主力的五一红包23仓位',
#   [{'label': 'Neutral', 'score': 0.996234118938446}],
#   '000524'),
#  ('岭南控股SZ000524',
#   [{'label': 'Neutral', 'score': 0.9949008226394653}],
#   '000524'),
#  ('炒股反人性明天一直字涨停',
#   [{'label': 'Neutral', 'score': 0.9875513911247253}],
#   '000524'),
#  ('这个就是垃圾股啥也不是真',
#   [{'label': 'Neutral', 'score': 0.9825232028961182}],
#   '000524'),
#  ('废票一个', [{'label': 'Neutral', 'score': 0.980705976486206}], '000524'),
#  ('大家一起把岭南控股提出飞行汽车板块',
#   [{'label': 'Neutral', 'score': 0.9973506927490234}],
#   '000524'),
#  ('1280明天有肉吃吗', [{'label': 'Neutral', 'score': 0.9774259924888611}], '000524'),
#  ('1300买1301卖走了不玩了涨起来吧',
#   [{'label': 'Neutral', 'score': 0.7060669660568237}],
#   '000524'),
#  ('走a', [{'label': 'Neutral', 'score': 0.9770556688308716}], '000524'),
#  ('不跟低空吗', [{'label': 'Neutral', 'score': 0.9854942560195923}], '000524'),
#  ('提前埋伏了好多天了准备吃肉了明天再低开直接满仓',
#   [{'label': 'Neutral', 'score': 0.9794262051582336}],
#   '000524'),
#  ('20日线建个仓', [{'label': 'Neutral', 'score': 0.990368127822876}], '000524'),
#  ('这货能不能行', [{'label': 'Neutral', 'score': 0.9701623916625977}], '000524'),
#  ('听哥给你们科普一下这几天虽然四根大阴线但是两次在二十日线反弹说明二十线支撑',
#   [{'label': 'Neutral', 'score': 0.9877030253410339}],
#   '000524'),
#  ('1洗盘五天225日大会3五一节要到了4此股是旅游消费前排票',
#   [{'label': 'Neutral', 'score': 0.9955904483795166}],
#   '000524'),
#  ('动能二号由绿色变蓝色蓝色已经变短说明弱势逐渐好转好转就是蓝色变红色',
#   [{'label': 'Neutral', 'score': 0.9937307834625244}],
#   '000524'),
#  ('转发', [{'label': 'Neutral', 'score': 0.9684391021728516}], '000524'),
#  ('开盘进的套了三个点明天有的赚吗',
#   [{'label': 'Neutral', 'score': 0.9722290635108948}],
#   '000524'),
#  ('岭南控股个人拙见不喜勿喷预测对了给点个赞就行短期支撑看1302不破可',
#   [{'label': 'Neutral', 'score': 0.9910310506820679}],
#   '000524'),
#  ('下午卖了明天择机买入', [{'label': 'Neutral', 'score': 0.9663518667221069}], '000524'),
#  ('明天到底是继续双针探底还是摸五日线我看摸五日线了吧',
#   [{'label': 'Neutral', 'score': 0.9953561425209045}],
#   '000524'),
#  ('明天接过国芳的旗帜', [{'label': 'Neutral', 'score': 0.9953051805496216}], '000524'),
#  ('吉林省2025年发放6亿元消费券支持各地开展促销活动',
#   [{'label': 'Neutral', 'score': 0.9962658286094666}],
#   '000524'),
#  ('远离lj股随便买个麦趣尔都吃肉',
#   [{'label': 'Neutral', 'score': 0.9937490224838257}],
#   '000524'),
#  ('天天在这里做t啊今天是1299买入1322卖出的',
#   [{'label': 'Neutral', 'score': 0.9963271021842957}],
#   '000524'),
#  ('黑龙江加快释放消费潜力深入实施提振消费专项行动',
#   [{'label': 'Positive', 'score': 0.9977810978889465}],
#   '000524'),
#  ('这票己经废了死气沉沉没人跟的',
#   [{'label': 'Neutral', 'score': 0.9703494310379028}],
#   '000524'),
#  ('你又拉起来干什么不到119附近你还拉慢慢磨洋工啊耗散户啊你好坏哦',
#   [{'label': 'Neutral', 'score': 0.924656331539154}],
#   '000524'),
#  ('136的成本明天能让我出去吗我只想出去',
#   [{'label': 'Neutral', 'score': 0.9905639886856079}],
#   '000524'),
#  ('明天期权交割日小心点吧',
#   [{'label': 'Neutral', 'score': 0.9126634001731873}],
#   '000524'),
#  ('看这样尾盘还得下来啊', [{'label': 'Neutral', 'score': 0.9625023007392883}], '000524'),
#  ('lj中的lj', [{'label': 'Neutral', 'score': 0.9811410903930664}], '000524'),
#  ('辛好早上开盘就把它给嘎了烂泥',
#   [{'label': 'Neutral', 'score': 0.981281578540802}],
#   '000524'),
#  ('大哥发威', [{'label': 'Neutral', 'score': 0.9837380647659302}], '000524'),
#  ('还好我机智割了转三峡', [{'label': 'Neutral', 'score': 0.9744139909744263}], '000524'),
#  ('扶不起的阿斗', [{'label': 'Neutral', 'score': 0.9596735239028931}], '000524'),
#  ('你不套人你会死的呀', [{'label': 'Neutral', 'score': 0.9756941795349121}], '000524'),
#  ('怎么卖不了', [{'label': 'Neutral', 'score': 0.7996302843093872}], '000524'),
#  ('三峡旅游马上启动速速抄底发大财了十个涨停目标价十五块',
#   [{'label': 'Neutral', 'score': 0.9640973210334778}],
#   '000524'),
#  ('我亏三十点', [{'label': 'Neutral', 'score': 0.9365543723106384}], '000524'),
#  ('离境退税即买即退服务措施推广至全国 政策利好免税旅游概念大涨',
#   [{'label': 'Positive', 'score': 0.9982606768608093}],
#   '000524'),
#  ('五一节旅游旺季快到了旅行社都忙着签合同今年旅游别踩死人啊',
#   [{'label': 'Neutral', 'score': 0.9689579606056213}],
#   '000524'),
#  ('8888有什么寓意有知道的嘛',
#   [{'label': 'Neutral', 'score': 0.985773503780365}],
#   '000524'),
#  ('明早不贪赚三个点就卖', [{'label': 'Neutral', 'score': 0.986903190612793}], '000524'),
#  ('明天不贪涨停就跑', [{'label': 'Neutral', 'score': 0.9804491400718689}], '000524'),
#  ('想13上车', [{'label': 'Neutral', 'score': 0.9903752207756042}], '000524'),
#  ('卖了屯子补仓你盘后送来公告4月28号就分红明天你不给个涨停对不起我',
#   [{'label': 'Neutral', 'score': 0.9911307096481323}],
#   '000524'),
#  ('明天回调上方压力太大',
#   [{'label': 'Negative', 'score': 0.9990271329879761}],
#   '000524'),
#  ('自贸概念叠加会不会来一波',
#   [{'label': 'Neutral', 'score': 0.9970839619636536}],
#   '000524'),
#  ('明天必破127看到1011块之间',
#   [{'label': 'Neutral', 'score': 0.9958875775337219}],
#   '000524'),
#  ('广东自贸区', [{'label': 'Neutral', 'score': 0.9932575225830078}], '000524'),
#  ('包来包去大肠包小肠这周周线反包月线无论怎么演绎也不改大阳线',
#   [{'label': 'Neutral', 'score': 0.9968605041503906}],
#   '000524'),
#  ('今天唯一不足就是缩量了没有盖过两根阴线但岭南一般会连涨三天本周必走主升',
#   [{'label': 'Neutral', 'score': 0.7657131552696228}],
#   '000524'),
#  ('赚钱就跑', [{'label': 'Neutral', 'score': 0.983022153377533}], '000524'),
#  ('今天普涨明天又分化轮到旅游了低成交量行情干调整股',
#   [{'label': 'Neutral', 'score': 0.9765719175338745}],
#   '000524'),
#  ('不要着急一定二波创新高',
#   [{'label': 'Neutral', 'score': 0.6843146085739136}],
#   '000524'),
#  ('在商贸文旅领域允许外商投资旅行社经营出境旅游业务在天津支持试点传统经典车保税',
#   [{'label': 'Neutral', 'score': 0.9971044659614563}],
#   '000524'),
#  ('尾盘成交8888手明天发发发发',
#   [{'label': 'Neutral', 'score': 0.9967455863952637}],
#   '000524'),
#  ('旅游的龙头应该是岭南吧明天带领旅游板块修复',
#   [{'label': 'Neutral', 'score': 0.9964136481285095}],
#   '000524'),
#  ('五一5天小长假前旅游酒店应该还有拉涨机会吧还是说早早出货呢',
#   [{'label': 'Neutral', 'score': 0.9959270358085632}],
#   '000524'),
#  ('51酒店都爆满呀', [{'label': 'Neutral', 'score': 0.9823657870292664}], '000524'),
#  ('刚好回本纠结要不要出掉',
#   [{'label': 'Neutral', 'score': 0.9661383032798767}],
#   '000524'),
#  ('20元以下股票几天跌5元依然有气没力没量能',
#   [{'label': 'Neutral', 'score': 0.8543461561203003}],
#   '000524'),
#  ('没用的浪费好行情我卖了你涨停吧',
#   [{'label': 'Neutral', 'score': 0.9708626866340637}],
#   '000524'),
#  ('怎么就不跌了', [{'label': 'Neutral', 'score': 0.9630715847015381}], '000524'),
#  ('完犊子了刚才1366追高进来了',
#   [{'label': 'Neutral', 'score': 0.9870362877845764}],
#   '000524'),
#  ('上呀还有一个星期准备出去浪了前提是你的提前给我准备粮草啊没点动劲怎么叫我怎',
#   [{'label': 'Neutral', 'score': 0.9889137148857117}],
#   '000524'),
#  ('上午的拉升是广州出了一个入境旅游的消息我直接追高了你雄起来啊',
#   [{'label': 'Positive', 'score': 0.7806827425956726}],
#   '000524'),
#  ('妹的其他全红就这个还在织布哎无语了',
#   [{'label': 'Neutral', 'score': 0.9859451651573181}],
#   '000524'),
#  ('快跑', [{'label': 'Neutral', 'score': 0.9564561247825623}], '000524'),
#  ('千万记住别听谁说啥因为那些都扯淡就记住一句话二十线1270破了就废了',
#   [{'label': 'Neutral', 'score': 0.991182804107666}],
#   '000524'),
#  ('明日主题前瞻字节Seed智能体模型UITARS15开源机构称算力基础设施将持续受益',
#   [{'label': 'Positive', 'score': 0.9980415105819702}],
#   '000524'),
#  ('四海恐慌五洲怒黄金避险飞九天又双叒叕周末了唯有抄底金矿股鹏欣资源华钰矿业等',
#   [{'label': 'Neutral', 'score': 0.9971954822540283}],
#   '000524'),
#  ('明天负几开', [{'label': 'Neutral', 'score': 0.9883606433868408}], '000524'),
#  ('再次提醒大家明天务必平开高开低开不到一个点都要跑还要继续下探11块左右才能',
#   [{'label': 'Neutral', 'score': 0.990885853767395}],
#   '000524'),
#  ('你们唱空吧我重仓的这个你们发利好我慌',
#   [{'label': 'Positive', 'score': 0.9345816969871521}],
#   '000524'),
#  ('岭南控股本周融资净买入145029万元居旅游酒店板块第八',
#   [{'label': 'Neutral', 'score': 0.7064997553825378}],
#   '000524'),
#  ('明天二十线不能破破了就',
#   [{'label': 'Neutral', 'score': 0.9741531610488892}],
#   '000524'),
#  ('四连阴千万记住明天破了二十线127就彻底废了',
#   [{'label': 'Neutral', 'score': 0.9868307113647461}],
#   '000524'),
#  ('明天最后一道屏障二十线1270破了二十线请大家别议论了因为议论也是扯淡',
#   [{'label': 'Neutral', 'score': 0.9899277091026306}],
#   '000524'),
#  ('目前庄家洗盘在二十线如果明天破了二十线1270那么大家就别议论了因为谁的',
#   [{'label': 'Neutral', 'score': 0.9968260526657104}],
#   '000524'),
#  ('目前缩量在二十线上明天如果破了二十线1270这股就不要在议论了因为谁的',
#   [{'label': 'Neutral', 'score': 0.9922754168510437}],
#   '000524'),
#  ('明天破了二十线就彻底结束',
#   [{'label': 'Neutral', 'score': 0.9858239889144897}],
#   '000524'),
#  ('跌停', [{'label': 'Neutral', 'score': 0.9835086464881897}], '000524'),
#  ('星期一在跌你就废了', [{'label': 'Neutral', 'score': 0.9863860607147217}], '000524'),
#  ('尾盘买进12万星期一能高开吗',
#   [{'label': 'Neutral', 'score': 0.9738811254501343}],
#   '000524'),
#  ('下周主线是旅游和消费我不信主力就这样一直出货压低股价预计下周一企稳上涨2个点',
#   [{'label': 'Positive', 'score': 0.8355328440666199}],
#   '000524'),
#  ('周一势必又套住一批心心念念想抄底的散户结果越抄底发现还在半山腰',
#   [{'label': 'Neutral', 'score': 0.9958534240722656}],
#   '000524'),
#  ('还有10天到五一', [{'label': 'Neutral', 'score': 0.9897068738937378}], '000524'),
#  ('周五就应该涨', [{'label': 'Neutral', 'score': 0.9896780252456665}], '000524'),
#  ('周一绿', [{'label': 'Neutral', 'score': 0.99039626121521}], '000524'),
#  ('利好', [{'label': 'Positive', 'score': 0.997879147529602}], '000524'),
#  ('1311全仓买入了下班',
#   [{'label': 'Neutral', 'score': 0.9853454232215881}],
#   '000524'),
#  ('再多的利好也抵挡不住下跌趋势越想抄底炒到只能是半山腰目前没有止跌迹象不信你',
#   [{'label': 'Neutral', 'score': 0.9135047197341919}],
#   '000524'),
#  ('走势不对减半仓', [{'label': 'Neutral', 'score': 0.9897224307060242}], '000524'),
#  ('就喜欢看吧里汪汪叫的想骗带血的筹码没门',
#   [{'label': 'Neutral', 'score': 0.9882469773292542}],
#   '000524'),
#  ('最怕是这种阴跌根本没低不如通通快快跌停还能有修复预期这个根本不用幻想还没',
#   [{'label': 'Neutral', 'score': 0.9846042990684509}],
#   '000524'),
#  ('相信我周一平开或者高开马上跑低开一点点都不要犹豫立马跑还没跌到位可能会在',
#   [{'label': 'Neutral', 'score': 0.9908851981163025}],
#   '000524'),
#  ('想回到16元要等三年了',
#   [{'label': 'Neutral', 'score': 0.9350766539573669}],
#   '000524'),
#  ('下星期还要一直跌还不跑',
#   [{'label': 'Neutral', 'score': 0.9315589070320129}],
#   '000524'),
#  ('是利好吗', [{'label': 'Positive', 'score': 0.993743360042572}], '000524'),
#  ('顶分型差不多了', [{'label': 'Neutral', 'score': 0.9879633188247681}], '000524'),
#  ('等跌到九元我会考虑一下',
#   [{'label': 'Neutral', 'score': 0.9685755372047424}],
#   '000524'),
#  ('已经卖了你可以涨了', [{'label': 'Neutral', 'score': 0.9337969422340393}], '000524'),
#  ('怎么反抽都没有双头都做不出来',
#   [{'label': 'Neutral', 'score': 0.974903404712677}],
#   '000524'),
#  ('广东自贸区龙头下周会涨吗',
#   [{'label': 'Positive', 'score': 0.9744275212287903}],
#   '000524'),
#  ('哎太6了周二尾盘五日线博弈周三破了就该走了硬是熬到今天尾盘割肉了这两天',
#   [{'label': 'Neutral', 'score': 0.9856268763542175}],
#   '000524'),
#  ('到底什么才是真的什么才是真的',
#   [{'label': 'Neutral', 'score': 0.9747241735458374}],
#   '000524'),
#  ('是利好吗', [{'label': 'Positive', 'score': 0.993743360042572}], '000524'),
#  ('这种A杀的票反弹也有限目前还没看到低11块左右可能有反弹但是还是向下趋势',
#   [{'label': 'Neutral', 'score': 0.9920104742050171}],
#   '000524'),
#  ('这垃圾周一清仓', [{'label': 'Neutral', 'score': 0.9912069439888}], '000524'),
#  ('旅游及酒店板块走低大连圣亚岭南控股跌停',
#   [{'label': 'Negative', 'score': 0.9911060929298401}],
#   '000524'),
#  ('这种没人性的票就算涨了也不要专门收割情怀的票特殊时期还故意跳水',
#   [{'label': 'Neutral', 'score': 0.9925313591957092}],
#   '000524'),
#  ('唉一直阴跌看这走势要回到11块准备清仓了',
#   [{'label': 'Neutral', 'score': 0.9588652849197388}],
#   '000524'),
#  ('一个个别做梦了周一赶紧清仓吧破位破到家了',
#   [{'label': 'Neutral', 'score': 0.9906414151191711}],
#   '000524'),
#  ('周一继续下杀清仓吧都被套了暂时上不去了',
#   [{'label': 'Neutral', 'score': 0.8667204976081848}],
#   '000524'),
#  ('看以往的走势都是往下走这股到顶短期就没往上走的你回看一下很恐怖的拿着拿着可',
#   [{'label': 'Neutral', 'score': 0.9676854610443115}],
#   '000524'),
#  ('逻辑跨境电商大热则离境退税弱化事实上转口贸易被堵了需追踪原产地80',
#   [{'label': 'Neutral', 'score': 0.9954999089241028}],
#   '000524'),
#  ('诛心杀融资杀配资杀量化12以下启动二融',
#   [{'label': 'Neutral', 'score': 0.9977260231971741}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了',
#   [{'label': 'Neutral', 'score': 0.9865190386772156}],
#   '000524'),
#  ('A股新变化分红超1万亿元龙头企业引领分红浪潮',
#   [{'label': 'Neutral', 'score': 0.9956098198890686}],
#   '000524'),
#  ('这股每次拉起都是a杀的不留意的赌徒很容易被骗a杀之后再起的几率极微自己看过',
#   [{'label': 'Neutral', 'score': 0.9949806332588196}],
#   '000524'),
#  ('广交会客商都不住东方宾馆中国大酒店吗',
#   [{'label': 'Neutral', 'score': 0.9932217597961426}],
#   '000524'),
#  ('割了吧兄弟们', [{'label': 'Neutral', 'score': 0.9825195074081421}], '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了',
#   [{'label': 'Neutral', 'score': 0.9865190386772156}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了',
#   [{'label': 'Neutral', 'score': 0.9865190386772156}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了',
#   [{'label': 'Neutral', 'score': 0.9865190386772156}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了',
#   [{'label': 'Neutral', 'score': 0.9865190386772156}],
#   '000524'),
#  ('兄弟们行情结末了', [{'label': 'Neutral', 'score': 0.9896765351295471}], '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了下',
#   [{'label': 'Neutral', 'score': 0.9898591637611389}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了下',
#   [{'label': 'Neutral', 'score': 0.9898591637611389}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了下',
#   [{'label': 'Neutral', 'score': 0.9898591637611389}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了下',
#   [{'label': 'Neutral', 'score': 0.9898591637611389}],
#   '000524'),
#  ('1低空经济与亿航智能合作2粤港自贸区3五一旅游将至天时地利只差人和了下',
#   [{'label': 'Neutral', 'score': 0.9898591637611389}],
#   '000524'),
#  ('1低空经济2粤港自贸区3五一将至天时地利只差人和了能不能当一次总龙头',
#   [{'label': 'Neutral', 'score': 0.9949280023574829}],
#   '000524'),
#  ('那么多利好的新闻还出了低空经济利好新闻要是利好主力提早就知道了股价说明一切',
#   [{'label': 'Positive', 'score': 0.8573688268661499}],
#   '000524'),
#  ('这个股A刹也太没理由了吧根本就没涨多少而且前面两个涨停拉的那么丝滑问题是没',
#   [{'label': 'Neutral', 'score': 0.9780176281929016}],
#   '000524'),
#  ('下周一要割肉不', [{'label': 'Neutral', 'score': 0.99275803565979}], '000524'),
#  ('岭南控股SZ000524',
#   [{'label': 'Neutral', 'score': 0.9949008226394653}],
#   '000524'),
#  ('下周还要跌11左右才能止跌企稳注意风险五一过后才能迎来新一轮的止跌企稳反弹',
#   [{'label': 'Neutral', 'score': 0.9468412399291992}],
#   '000524'),
#  ('岭南控股应该会有二浪该股有主力潜伏成本低前几天是出货或者是阶段性套利不',
#   [{'label': 'Neutral', 'score': 0.9964593052864075}],
#   '000524'),
#  ('回踩五日不破五日线附近可吸',
#   [{'label': 'Neutral', 'score': 0.994703471660614}],
#   '000524'),
#  ('商务部将加快出台优化离境退税等政策措施',
#   [{'label': 'Positive', 'score': 0.5825071930885315}],
#   '000524'),
#  ('五一黄金周旅游业要大涨这是天时',
#   [{'label': 'Neutral', 'score': 0.7372395396232605}],
#   '000524'),
#  ('明日一根大阳线不服的明天来辩',
#   [{'label': 'Neutral', 'score': 0.9904127717018127}],
#   '000524'),
#  ('打了个底仓不知对错', [{'label': 'Neutral', 'score': 0.9788979291915894}], '000524'),
#  ('走成这样唯一的解释就是跟的免税概念免税连跌几天了',
#   [{'label': 'Negative', 'score': 0.8019760251045227}],
#   '000524'),
#  ('为什么这么个跌法这几天大盘这么稳',
#   [{'label': 'Neutral', 'score': 0.9801249504089355}],
#   '000524'),
#  ('明天大涨要么就是大跌', [{'label': 'Neutral', 'score': 0.989346444606781}], '000524'),
#  ('此票为什么跌这样两个原因1有违规暴雷2为了下轮主升做准备',
#   [{'label': 'Neutral', 'score': 0.9272247552871704}],
#   '000524'),
#  ('今天买进基本上没亏没赚上午十一点与下午开盘有资金博弈的迹象不像是拉高出货但',
#   [{'label': 'Neutral', 'score': 0.9951608777046204}],
#   '000524'),
#  ('明天要跌停吗', [{'label': 'Neutral', 'score': 0.9875538349151611}], '000524'),
#  ('小散户赶紧跑', [{'label': 'Neutral', 'score': 0.9855135083198547}], '000524'),
#  ('主力跑了明天是游资跑路',
#   [{'label': 'Neutral', 'score': 0.9933271408081055}],
#   '000524'),
#  ('2025年4月16日中共中央政治局委员外交部长王毅和马来西亚内政部长赛夫丁分',
#   [{'label': 'Neutral', 'score': 0.9961549639701843}],
#   '000524'),
#  ('全是散户在里面', [{'label': 'Neutral', 'score': 0.9908537864685059}], '000524'),
#  ('破了10日线', [{'label': 'Neutral', 'score': 0.9769369959831238}], '000524'),
#  ('还有两天下杀', [{'label': 'Neutral', 'score': 0.9811086058616638}], '000524'),
#  ('周线的五日线看支撑', [{'label': 'Neutral', 'score': 0.9728353023529053}], '000524'),
#  ('下轮又要到国庆节了5个月的阴跌不归路实在难熬啊',
#   [{'label': 'Negative', 'score': 0.9456495046615601}],
#   '000524'),
#  ('周末绝对大利空', [{'label': 'Positive', 'score': 0.9934291243553162}], '000524'),
#  ('胜败乃兵家常事全世界韭菜团结起来逆袭妖股抓手每日关注买在无人问津时卖在人',
#   [{'label': 'Neutral', 'score': 0.996013879776001}],
#   '000524'),
#  ('航旅纵横最新大数据显示截至4月17日五一假期国内航线机票预订量超333万张',
#   [{'label': 'Neutral', 'score': 0.9977141618728638}],
#   '000524'),
#  ('成本15块有机会回本吗',
#   [{'label': 'Neutral', 'score': 0.9854997992515564}],
#   '000524'),
#  ('这货不会有雷吧旅游酒店这两天涨这么好',
#   [{'label': 'Positive', 'score': 0.8794506788253784}],
#   '000524'),
#  ('岭南控股明天个人感觉会收阳两个理由第一点博周一会议预期加快推进服务业扩大',
#   [{'label': 'Positive', 'score': 0.9987074136734009}],
#   '000524'),
#  ('老庄清仓跑路了吗这么跌',
#   [{'label': 'Neutral', 'score': 0.9723119735717773}],
#   '000524'),
#  ('这票财务有问题', [{'label': 'Negative', 'score': 0.9767757654190063}], '000524'),
#  ('跌停板再说', [{'label': 'Neutral', 'score': 0.9906367659568787}], '000524'),
#  ('我走了留下的发财', [{'label': 'Neutral', 'score': 0.9864612221717834}], '000524'),
#  ('谁在顶买了', [{'label': 'Neutral', 'score': 0.9897597432136536}], '000524'),
#  ...]

# %%
final_scores = []
for result in results_apple:
    sentiment = result[1][0]
    label = sentiment["label"]
    score = sentiment["score"]

    # LABEL_0: Negative
    # LABEL_1: Neutral
    # LABEL_2: Positive
    if label == "Positive":
        final_scores.append(score)
    elif label == "Negative":
        final_scores.append(-1*score)
    else:
        final_scores.append(0)
df_apple.loc[:,"score"] = final_scores
df_apple
# Out:
#       ticker        Date                                  title  read_count  \
# 0     688981  2025-05-02                            A股进口替代50强出炉       13546
# 1     688981  2025-05-07                 一起举报那个满融满仓中芯国际刷屏可耻把他封了         188
# 2     688981  2025-05-07                        明天的一季度业绩不知道什么样子         116
# 3     688981  2025-04-25  去年以来已经涨的够多了现可以离场了大盘上20天线中芯跌破20天线君子不立危        1042
# 4     688981  2025-05-07                             2收盘明天可以起飞了          18
# ...      ...         ...                                    ...         ...
# 1388  002475  2025-04-26           立讯精密2024年净利润13366亿元 同比增长2203        2801
# 1389  002475  2025-04-26                               危险了热度这么高         266
# 1390  002475  2025-04-26                              怎么回事热度这么高         321
# 1391  002475  2025-04-26                     这种机构股记住一句话业绩出来就是出货         301
# 1392  002475  2025-04-26                              看不到成长性的公司         255
#
#          score
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.796719
# 4     0.000000
# ...        ...
# 1388  0.998987
# 1389  0.000000
# 1390  0.000000
# 1391  0.000000
# 1392  0.000000
#
# [1393 rows x 5 columns]

# %%
import pandas as pd

# 每日加权平均分，按股票代码分组
# 首先确保日期格式正确
df_apple["Date"] = pd.to_datetime(df_apple["Date"]).dt.date
# 计算加权分数
df_apple["weighted_score"] = df_apple["score"] * df_apple["read_count"]
# 按日期和股票代码分组计算加权平均
daily_avg = df_apple.groupby(["Date", "ticker"]).apply(
    lambda x: x["weighted_score"].sum() / x["read_count"].sum() if x["read_count"].sum() > 0 else 0
).reset_index(name="score")
# 4. 输出结果
print("每日加权平均分：")
print(daily_avg)
# Out:
# 每日加权平均分：
#           Date  ticker     score
# 0   2025-02-09  688981  0.997773
# 1   2025-02-11  688981  0.000000
# 2   2025-02-14  688981  0.998067
# 3   2025-02-17  002475  0.000000
# 4   2025-02-18  688981  0.997005
# ..         ...     ...       ...
# 91  2025-05-06  002475  0.061942
# 92  2025-05-06  688981  0.004948
# 93  2025-05-07  000524  0.033055
# 94  2025-05-07  002475 -0.006261
# 95  2025-05-07  688981  0.000114
#
# [96 rows x 3 columns]
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/1019498541.py:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   daily_avg = df_apple.groupby(["Date", "ticker"]).apply(

# %%
df_apple.describe()
# Out:
#          read_count        score  weighted_score
# count   1393.000000  1393.000000     1393.000000
# mean    1355.531228     0.066324      227.025068
# std     5209.317925     0.365279     2768.273693
# min        1.000000    -0.999027   -26246.925520
# 25%      136.000000     0.000000        0.000000
# 50%      253.000000     0.000000        0.000000
# 75%      484.000000     0.000000        0.000000
# max    88714.000000     0.999254    78593.575779

# %%
import akshare as ak
from datetime import datetime, timedelta

# 定义股票列表和数据时间范围（注意：akshare主要支持A股，这里以A股代码为例）
tickers = ['688981', '000524', '002475']  
# 设置开始和结束日期 2.9-5.7
start_date = "20250209"
end_date = "20250507"

# 创建一个空的DataFrame来存储所有股票的数据
all_data = pd.DataFrame()
# 循环获取每只股票的数据
for ticker in tickers:
    # 使用 akshare 获取股票历史数据
    data = ak.stock_zh_a_hist(symbol=ticker, period="daily", start_date=start_date, end_date=end_date)
    # 数据处理
    data = data.rename(columns={
        "日期": "Date",
        "收盘": "close",
    })[["Date", "close"]]  # 只保留这两列
    # 添加股票代码列
    data['ticker'] = ticker
    # 将日期转换为字符串格式
    data['Date'] = pd.to_datetime(data['Date']).dt.strftime('%Y-%m-%d')
    # 合并数据
    all_data = pd.concat([all_data, data], ignore_index=True)
# 将日期转换为datetime格式
all_data['Date'] = pd.to_datetime(all_data['Date'])
# 打印合并后的数据
print(all_data.head())
# Out:
#         Date   close  ticker
# 0 2025-02-10  103.85  688981
# 1 2025-02-11  100.86  688981
# 2 2025-02-12  104.32  688981
# 3 2025-02-13  101.11  688981
# 4 2025-02-14   99.08  688981

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from matplotlib.font_manager import FontProperties

# 设置中文字体
font = FontProperties(fname='/System/Library/Fonts/STHeiti Medium.ttc')  # macOS中文黑体

# 将值数组转换为数据集矩阵
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        dataX.append(dataset[i:(i+look_back), :])
        dataY.append(dataset[i + look_back, 0])  # 我们只预测收盘价
    return np.array(dataX), np.array(dataY)

# 设置随机种子以便结果可复现
np.random.seed(42)
tf.random.set_seed(42)

# 将原始daily_avg数据按ticker分组
tickers = daily_avg['ticker'].unique()
print(f"处理的股票代码: {tickers}")

# 创建一个大的图表来显示所有股票的预测结果
plt.figure(figsize=(18, 18))

# 为每个股票代码分别创建模型和预测
for i, ticker in enumerate(tickers):
    print(f"\n处理股票 {ticker}...")
    
    # 筛选当前股票的数据
    ticker_daily_avg = daily_avg[daily_avg['ticker'] == ticker].copy()
    
    # 获取对应的股价数据
    ticker_data = all_data[all_data['ticker'] == ticker]
    # print(ticker_data.head())

    # 处理日期格式
    ticker_daily_avg['Date'] = pd.to_datetime(ticker_daily_avg['Date'])
    ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
    
    # 补全缺失日期,以data的日期为准
    ticker_daily_avg = ticker_daily_avg.set_index('Date').reindex(ticker_data['Date']).reset_index()
    
    # 对缺失score的日期插值
    ticker_daily_avg['score'] = ticker_daily_avg['score'].interpolate(method='linear')
    ticker_daily_avg['score'] = ticker_daily_avg['score'].fillna(0)  # 填充可能的缺失值
    
    # 将日期转换为字符串格式
    ticker_daily_avg['Date'] = ticker_daily_avg['Date'].dt.strftime('%Y-%m-%d')
    ticker_data['Date'] = ticker_data['Date'].dt.strftime('%Y-%m-%d')
    
    # 合并当前股票的情感数据和价格数据
    ticker_merged_data = pd.merge(ticker_daily_avg, ticker_data[['Date', 'close']], on='Date')
    ticker_merged_data.set_index('Date', inplace=True)
    
    # 添加情感特征工程
    ticker_merged_data['score_lag1'] = ticker_merged_data['score'].shift(1)  # 前一天的情绪分数
    ticker_merged_data['score_ma3'] = ticker_merged_data['score'].rolling(window=3).mean()  # 3天平均情绪
    ticker_merged_data['score_ma5'] = ticker_merged_data['score'].rolling(window=5).mean()  # 5天平均情绪
    
    # 删除NaN值
    ticker_merged_data = ticker_merged_data.dropna()
    
    # 如果数据太少，则跳过
    if len(ticker_merged_data) < 10:
        print(f"警告: 股票 {ticker} 数据不足，跳过")
        continue
    
    # 选择特征 - 收盘价和所有情绪相关特征
    features = ['close', 'score_ma5']
    dataset = ticker_merged_data[features].values.astype('float32')
    
    # 规范化数据集
    scaler = MinMaxScaler(feature_range=(0, 1))
    dataset_scaled = scaler.fit_transform(dataset)
    
    # 分割为训练集和测试集
    train_size = int(len(dataset_scaled) * 0.67)
    test_size = len(dataset_scaled) - train_size
    train, test = dataset_scaled[0:train_size,:], dataset_scaled[train_size:len(dataset_scaled),:]
    
    # 重新整形为 X=t 和 Y=t+1
    look_back = 3
    trainX, trainY = create_dataset(train, look_back)
    testX, testY = create_dataset(test, look_back)
    
    # 创建并拟合LSTM网络
    model = Sequential()
    model.add(LSTM(50, input_shape=(look_back, len(features))))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(trainX, trainY, epochs=100, batch_size=16, verbose=0)
    
    # 进行预测
    trainPredict = model.predict(trainX)
    testPredict = model.predict(testX)
    
    # 创建占位数组用于反归一化
    trainY_reshaped = np.zeros((len(trainY), len(features)))
    trainY_reshaped[:,0] = trainY
    trainY_reshaped[:,1] = train[:len(trainY), 1]
    
    testY_reshaped = np.zeros((len(testY), len(features)))
    testY_reshaped[:,0] = testY
    testY_reshaped[:,1] = test[:len(testY), 1]
    
    trainPredict_reshaped = np.zeros((len(trainPredict), len(features)))
    trainPredict_reshaped[:,0] = trainPredict[:,0]
    trainPredict_reshaped[:,1] = train[:len(trainPredict), 1]
    
    testPredict_reshaped = np.zeros((len(testPredict), len(features)))
    testPredict_reshaped[:,0] = testPredict[:,0]
    testPredict_reshaped[:,1] = test[:len(testPredict), 1]
    
    # 反归一化
    trainPredict = scaler.inverse_transform(trainPredict_reshaped)[:,0]
    trainY = scaler.inverse_transform(trainY_reshaped)[:,0]
    testPredict = scaler.inverse_transform(testPredict_reshaped)[:,0]
    testY = scaler.inverse_transform(testY_reshaped)[:,0]
    
    # 计算均方根误差
    trainScore = np.sqrt(mean_squared_error(trainY, trainPredict))
    testScore = np.sqrt(mean_squared_error(testY, testPredict))
    print(f'{ticker} 训练集得分: {trainScore:.2f} RMSE')
    print(f'{ticker} 测试集得分: {testScore:.2f} RMSE')
    
    # 准备绘图数据
    dataset_inv = scaler.inverse_transform(dataset_scaled)
    actual_close = dataset_inv[:,0]
    
    # 创建预测结果的完整序列
    trainPredictPlot = np.empty_like(actual_close)
    trainPredictPlot[:] = np.nan
    trainPredictPlot[look_back:look_back+len(trainPredict)] = trainPredict
    
    testPredictPlot = np.empty_like(actual_close)
    testPredictPlot[:] = np.nan
    testPredictPlot[len(trainPredict)+(look_back*2)+1:len(actual_close)-1] = testPredict
    
    # 在子图中绘制当前股票的预测结果
    plt.subplot(len(tickers), 1, i+1)
    plt.plot(actual_close, label='实际价格')
    plt.plot(trainPredictPlot, label='训练集预测')
    plt.plot(testPredictPlot, label='测试集预测')
    plt.title(f'股票 {ticker} 价格预测', fontproperties=font)
    plt.xlabel('时间', fontproperties=font)
    plt.ylabel('价格', fontproperties=font)
    plt.legend(prop=font)

plt.tight_layout()
plt.show()

# 可选：保存每个股票的预测结果到csv文件
for ticker in tickers:
    ticker_daily_avg = daily_avg[daily_avg['ticker'] == ticker]
    if not ticker_daily_avg.empty:
        ticker_daily_avg.to_csv(f"{ticker}_predictions.csv", index=False)
# Out:
# 处理的股票代码: ['688981' '002475' '000524']
#
# 处理股票 688981...
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/328184186.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/328184186.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = ticker_data['Date'].dt.strftime('%Y-%m-%d')
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 688981 训练集得分: 1.35 RMSE
# 688981 测试集得分: 2.30 RMSE
#
# 处理股票 002475...
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/328184186.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/328184186.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = ticker_data['Date'].dt.strftime('%Y-%m-%d')
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 002475 训练集得分: 0.44 RMSE
# 002475 测试集得分: 0.89 RMSE
#
# 处理股票 000524...
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/328184186.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/328184186.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = ticker_data['Date'].dt.strftime('%Y-%m-%d')
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 000524 训练集得分: 0.96 RMSE
# 000524 测试集得分: 1.39 RMSE
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     pass
#     342 else:
# --> 343     return printer(obj)
#     344 # Finally look for special method names
#     345 method = get_real_method(obj, self.print_method)
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     167     from matplotlib.backend_bases import FigureCanvasBase
#     168     FigureCanvasBase(fig)
# --> 170 fig.canvas.print_figure(bytes_io, **kw)
#     171 data = bytes_io.getvalue()
#     172 if fmt == 'svg':
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backend_bases.py:2175, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2172     # we do this instead of `self.figure.draw_without_rendering`
#    2173     # so that we can inject the orientation
#    2174     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2175         self.figure.draw(renderer)
#    2176 if bbox_inches:
#    2177     if bbox_inches == "tight":
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:3101, in _AxesBase.draw(self, renderer)
#    3098     for spine in self.spines.values():
#    3099         artists.remove(spine)
# -> 3101 self._update_title_position(renderer)
#    3103 if not self.axison:
#    3104     for _axis in self._axis_map.values():
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axes/_base.py:3045, in _AxesBase._update_title_position(self, renderer)
#    3043 top = max(top, bb.ymax)
#    3044 if title.get_text():
# -> 3045     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3046     if ax.yaxis.offsetText.get_text():
#    3047         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/axis.py:1388, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1386 # take care of label
#    1387 if self.label.get_visible():
# -> 1388     bb = self.label.get_window_extent(renderer)
#    1389     # for constrained/tight_layout, we want to ignore the label's
#    1390     # width/height because the adjustments they make can't be improved.
#    1391     # this code collapses the relevant direction
#    1392     if for_layout_only:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/text.py:959, in Text.get_window_extent(self, renderer, dpi)
#     954     raise RuntimeError(
#     955         "Cannot get window extent of text w/o renderer. You likely "
#     956         "want to call 'figure.draw_without_rendering()' first.")
#     958 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 959     bbox, info, descent = self._get_layout(self._renderer)
#     960     x, y = self.get_unitless_position()
#     961     x, y = self.get_transform().transform((x, y))
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/text.py:373, in Text._get_layout(self, renderer)
#     370 ys = []
#     372 # Full vertical extent of font, including ascenders and descenders:
# --> 373 _, lp_h, lp_d = _get_text_metrics_with_cache(
#     374     renderer, "lp", self._fontproperties,
#     375     ismath="TeX" if self.get_usetex() else False, dpi=self.figure.dpi)
#     376 min_dy = (lp_h - lp_d) * self._linespacing
#     378 for i, line in enumerate(lines):
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/text.py:69, in _get_text_metrics_with_cache(renderer, text, fontprop, ismath, dpi)
#      66 """Call ``renderer.get_text_width_height_descent``, caching the results."""
#      67 # Cached based on a copy of fontprop so that later in-place mutations of
#      68 # the passed-in argument do not mess up the cache.
# ---> 69 return _get_text_metrics_with_cache_impl(
#      70     weakref.ref(renderer), text, fontprop.copy(), ismath, dpi)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/text.py:77, in _get_text_metrics_with_cache_impl(renderer_ref, text, fontprop, ismath, dpi)
#      73 @functools.lru_cache(4096)
#      74 def _get_text_metrics_with_cache_impl(
#      75         renderer_ref, text, fontprop, ismath, dpi):
#      76     # dpi is unused, but participates in cache invalidation (via the renderer).
# ---> 77     return renderer_ref().get_text_width_height_descent(text, fontprop, ismath)
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:219, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     215     ox, oy, width, height, descent, font_image = \
#     216         self.mathtext_parser.parse(s, self.dpi, prop)
#     217     return width, height, descent
# --> 219 font = self._prepare_font(prop)
#     220 font.set_text(s, 0.0, flags=get_hinting_flag())
#     221 w, h = font.get_width_height()  # width and height of unrotated string
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/backends/backend_agg.py:253, in RendererAgg._prepare_font(self, font_prop)
#     249 def _prepare_font(self, font_prop):
#     250     """
#     251     Get the `.FT2Font` for *font_prop*, clear its buffer, and set its size.
#     252     """
# --> 253     font = get_font(_fontManager._find_fonts_by_props(font_prop))
#     254     font.clear()
#     255     size = font_prop.get_size_in_points()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/font_manager.py:1560, in get_font(font_filepaths, hinting_factor)
#    1557 if hinting_factor is None:
#    1558     hinting_factor = mpl.rcParams['text.hinting_factor']
# -> 1560 return _get_font(
#    1561     # must be a tuple to be cached
#    1562     paths,
#    1563     hinting_factor,
#    1564     _kerning_factor=mpl.rcParams['text.kerning_factor'],
#    1565     # also key on the thread ID to prevent segfaults with multi-threading
#    1566     thread_id=threading.get_ident()
#    1567 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/font_manager.py:1502, in _get_font(font_filepaths, hinting_factor, _kerning_factor, thread_id)
#    1499 @lru_cache(64)
#    1500 def _get_font(font_filepaths, hinting_factor, *, _kerning_factor, thread_id):
#    1501     first_fontpath, *rest = font_filepaths
# -> 1502     return ft2font.FT2Font(
#    1503         first_fontpath, hinting_factor,
#    1504         _fallback_list=[
#    1505             ft2font.FT2Font(
#    1506                 fpath, hinting_factor,
#    1507                 _kerning_factor=_kerning_factor
#    1508             )
#    1509             for fpath in rest
#    1510         ],
#    1511         _kerning_factor=_kerning_factor
#    1512     )
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/xiaojingze/股票情感分析/C:/Windows/Fonts/simhei.ttf'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
from matplotlib.font_manager import FontProperties
from tensorflow.keras.models import load_model  # 可选：如果需要保存/加载模型

# 设置中文字体
font = FontProperties(fname='/System/Library/Fonts/STHeiti Medium.ttc')  # macOS中文黑体

# 1. 使用LSTM模型的预测结果计算预期收益率
# ===================================================

# 存储每只股票的预测结果和预测收益率
stock_predictions = {}
stock_predicted_returns = {}

# 为每只股票处理预测数据
for ticker in tickers:
    print(f"\n准备股票 {ticker} 的预测收益率...")
    
    # 筛选当前股票的数据
    ticker_data = all_data[all_data['ticker'] == ticker]
    ticker_daily_avg = daily_avg[daily_avg['ticker'] == ticker]
    
    if not ticker_data.empty and not ticker_daily_avg.empty:
        # 准备和合并数据，与先前的LSTM预测代码相同
        ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
        ticker_daily_avg['Date'] = pd.to_datetime(ticker_daily_avg['Date'])
        
        # 合并价格和情感数据
        ticker_merged_data = pd.merge(ticker_data, ticker_daily_avg, on='Date', how='inner')
        ticker_merged_data.set_index('Date', inplace=True)
        
        # 添加情感特征工程
        ticker_merged_data['score_lag1'] = ticker_merged_data['score'].shift(1)
        ticker_merged_data['score_ma3'] = ticker_merged_data['score'].rolling(window=3).mean()
        ticker_merged_data['score_ma5'] = ticker_merged_data['score'].rolling(window=5).mean()
        ticker_merged_data = ticker_merged_data.dropna()
        
        if len(ticker_merged_data) < 10:
            print(f"警告: 股票 {ticker} 数据不足，使用默认预期收益率")
            # 使用默认预期收益率
            stock_predicted_returns[ticker] = pd.Series(0.0005, index=pd.date_range(start='2025-01-01', periods=10))
            continue
        
        # 选择特征并进行预处理
        features = ['close', 'score_ma5']
        dataset = ticker_merged_data[features].values.astype('float32')
        scaler = MinMaxScaler(feature_range=(0, 1))
        dataset_scaled = scaler.fit_transform(dataset)
        
        # 分割为训练集和测试集
        train_size = int(len(dataset_scaled) * 0.50)
        test_size = len(dataset_scaled) - train_size
        train, test = dataset_scaled[0:train_size,:], dataset_scaled[train_size:len(dataset_scaled),:]
        
        # 重新整形为 X=t 和 Y=t+1
        look_back = 3
        trainX, trainY = create_dataset(train, look_back)
        testX, testY = create_dataset(test, look_back)
        
        # 创建并拟合LSTM网络 (或加载已保存的模型)
        model = Sequential()
        model.add(LSTM(50, input_shape=(look_back, len(features))))
        model.add(Dense(1))
        model.compile(loss='mean_squared_error', optimizer='adam')
        model.fit(trainX, trainY, epochs=100, batch_size=16, verbose=0)
        
        # 进行预测
        trainPredict = model.predict(trainX)
        testPredict = model.predict(testX, verbose=0)
        
        # 反归一化处理
        testPredict_reshaped = np.zeros((len(testPredict), len(features)))
        testPredict_reshaped[:,0] = testPredict[:,0]
        testPredict_reshaped[:,1] = test[:len(testPredict), 1]
        
        testY_reshaped = np.zeros((len(testY), len(features)))
        testY_reshaped[:,0] = testY
        testY_reshaped[:,1] = test[:len(testY), 1]
        
        # 反归一化
        testPredict_prices = scaler.inverse_transform(testPredict_reshaped)[:,0]
        testY_prices = scaler.inverse_transform(testY_reshaped)[:,0]
        
        # 存储预测结果
        stock_predictions[ticker] = testPredict_prices
        
        # 2. 计算预测收益率: 根据预测价格变动计算
        # 使用(第二天价格/第一天价格)-1作为收益率
        predicted_returns = np.zeros(len(testPredict_prices)-1)
        for i in range(len(testPredict_prices)-1):
            predicted_returns[i] = (testPredict_prices[i+1]/testPredict_prices[i]) - 1
        
        # 将预测收益率转换为pandas Series以便后续使用
        # 假设测试集的日期从ticker_merged_data的后三分之一开始
        test_dates = ticker_merged_data.index[train_size+look_back+1:train_size+look_back+1+len(predicted_returns)]
        stock_predicted_returns[ticker] = pd.Series(predicted_returns, index=test_dates)
        
        print(f"股票 {ticker} 的平均预测收益率: {predicted_returns.mean():.4f}")

# 3. 创建预期收益率数据框
# ===================================================

# 创建预测收益率数据框 - 使用相同的日期索引合并所有股票
predicted_returns_df = pd.DataFrame()

for ticker in tickers:
    if ticker in stock_predicted_returns:
        predicted_returns_df[ticker] = stock_predicted_returns[ticker]

# 删除缺失值并确保所有股票在相同日期有数据
predicted_returns_df = predicted_returns_df.dropna()

# 4. 计算协方差矩阵
# ===================================================

# 计算基于预测收益率的协方差矩阵
# 这里我们可以选择使用预测收益率自身的协方差或使用实际历史收益率的协方差
if len(predicted_returns_df) >= 10:  # 如果有足够多的预测数据点
    print("使用预测收益率计算协方差矩阵")
    cov_matrix = predicted_returns_df.cov()
else:
    print("预测数据点不足，使用实际历史收益率计算协方差矩阵")
    # 计算实际历史收益率
    returns_df = pd.DataFrame()
    for ticker in tickers:
        ticker_data = all_data[all_data['ticker'] == ticker].copy()
        if len(ticker_data) > 0:
            ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
            ticker_data.set_index('Date', inplace=True)
            ticker_data['return'] = ticker_data['close'].pct_change()
            returns_df[ticker] = ticker_data['return']
    
    returns_df = returns_df.dropna()
    cov_matrix = returns_df.cov()

# 5. 准备预期收益率
# ===================================================

# 使用预测收益率的均值作为预期收益率
expected_returns = {ticker: predicted_returns_df[ticker].mean() for ticker in predicted_returns_df.columns}

# 打印预期收益率以便验证
print("\n各股票预期日收益率:")
for ticker, exp_return in expected_returns.items():
    print(f"{ticker}: {exp_return*100:.4f}%")

# 6. 投资组合优化函数
# ===================================================

# 计算投资组合的预期收益率
def portfolio_expected_return(weights, returns):
    return np.sum(weights * np.array(list(returns.values())))

# 计算投资组合的波动率（风险）
def portfolio_volatility(weights, cov_matrix):
    variance = np.dot(weights.T, np.dot(cov_matrix, weights))
    # Ensure variance is not negative due to precision errors
    return np.sqrt(np.maximum(0, variance))

# 计算夏普比率 (风险调整后的收益)
def sharpe_ratio(weights, returns, cov_matrix, risk_free_rate=0.01):
    return (portfolio_expected_return(weights, returns) - risk_free_rate) / portfolio_volatility(weights, cov_matrix)

# 目标函数: 最大化夏普比率
def negative_sharpe_ratio(weights, returns, cov_matrix, risk_free_rate=0.01):
    return -sharpe_ratio(weights, returns, cov_matrix, risk_free_rate)

# 约束条件: 权重总和为1
def weight_sum_constraint(weights):
    return np.sum(weights) - 1

# 7. 投资组合优化
# ===================================================

# 初始权重 (等比例分配)
n_assets = len(tickers)
initial_weights = np.ones(n_assets) / n_assets

# 优化求解 - 最大夏普比率投资组合
bounds = tuple((0.05, 0.6) for _ in range(n_assets))
constraints = {'type': 'eq', 'fun': weight_sum_constraint}

optimal_sharpe_result = minimize(
    negative_sharpe_ratio, 
    initial_weights, 
    args=(expected_returns, cov_matrix),
    method='SLSQP',
    bounds=bounds,
    constraints=constraints
)

optimal_sharpe_weights = optimal_sharpe_result['x']

# 最小波动率投资组合
def min_volatility(weights, cov_matrix):
    return portfolio_volatility(weights, cov_matrix)

min_vol_result = minimize(
    min_volatility,
    initial_weights,
    args=(cov_matrix,),
    method='SLSQP',
    bounds=bounds,
    constraints=constraints
)

min_vol_weights = min_vol_result['x']

# 8. 显示投资组合优化结果
# ===================================================

print("\n====== 投资组合优化结果（基于LSTM预测）======")

print("\n最优夏普比率投资组合 (最佳风险收益比):")
for i, ticker in enumerate(tickers):
    print(f"{ticker}: {optimal_sharpe_weights[i]*100:.2f}%")

expected_return = portfolio_expected_return(optimal_sharpe_weights, expected_returns)
expected_volatility = portfolio_volatility(optimal_sharpe_weights, cov_matrix)
expected_sharpe = sharpe_ratio(optimal_sharpe_weights, expected_returns, cov_matrix)

print(f"预期每日收益率: {expected_return*100:.4f}%")
print(f"预期每日波动率: {expected_volatility*100:.4f}%")
print(f"预期年化收益率: {expected_return*252*100:.2f}%")
print(f"预期年化波动率: {expected_volatility*np.sqrt(252)*100:.2f}%")
print(f"夏普比率: {expected_sharpe:.4f}")

print("\n最小波动率投资组合 (最低风险):")
for i, ticker in enumerate(tickers):
    print(f"{ticker}: {min_vol_weights[i]*100:.2f}%")

min_vol_return = portfolio_expected_return(min_vol_weights, expected_returns)
min_vol_volatility = portfolio_volatility(min_vol_weights, cov_matrix)
min_vol_sharpe = sharpe_ratio(min_vol_weights, expected_returns, cov_matrix)

print(f"预期每日收益率: {min_vol_return*100:.4f}%")
print(f"预期每日波动率: {min_vol_volatility*100:.4f}%")
print(f"预期年化收益率: {min_vol_return*252*100:.2f}%")
print(f"预期年化波动率: {min_vol_volatility*np.sqrt(252)*100:.2f}%")
print(f"夏普比率: {min_vol_sharpe:.4f}")

# 9. 可视化投资组合权重
# ===================================================

plt.figure(figsize=(15, 10))

# 最优夏普比率投资组合
plt.subplot(2, 1, 1)
plt.pie(optimal_sharpe_weights, labels=tickers, autopct='%1.1f%%', startangle=90)
plt.title('基于LSTM预测的最优夏普比率投资组合', fontproperties=font, fontsize=14)

# 最小波动率投资组合
plt.subplot(2, 1, 2)
plt.pie(min_vol_weights, labels=tickers, autopct='%1.1f%%', startangle=90)
plt.title('基于LSTM预测的最小波动率投资组合', fontproperties=font, fontsize=14)

plt.tight_layout()
plt.show()

# 10. 根据风险偏好推荐投资组合
# ===================================================

def recommend_portfolio(risk_score, expected_returns, cov_matrix, tickers):
    """根据风险评分推荐投资组合"""
    n_assets = len(tickers)
    initial_weights = np.ones(n_assets) / n_assets
    
    # 根据风险偏好设置不同的权重约束和优化目标
    if risk_score <= 20:  # 极低风险
        bounds = tuple((0.15, 0.40) for _ in range(n_assets))
        title = "极低风险投资组合"
        objective = min_volatility  # 目标是最小化波动率
        objective_args = (cov_matrix,)
        explanation = "此投资组合追求最低的风险，适合风险承受能力极低的投资者"
    elif risk_score <= 40:  # 低风险
        bounds = tuple((0.10, 0.50) for _ in range(n_assets))
        title = "低风险投资组合"
        objective = min_volatility  # 目标仍是最小化波动率，但限制更宽松
        objective_args = (cov_matrix,)
        explanation = "此投资组合追求较低风险，但允许更大的股票配置灵活性"
    elif risk_score <= 60:  # 中等风险
        bounds = tuple((0.05, 0.60) for _ in range(n_assets))
        title = "平衡型投资组合"
        objective = negative_sharpe_ratio  # 目标是优化风险回报比
        objective_args = (expected_returns, cov_matrix)
        explanation = "此投资组合平衡风险和回报，适合大多数投资者"
    elif risk_score <= 80:  # 高风险
        bounds = tuple((0.05, 0.70) for _ in range(n_assets))
        title = "进取型投资组合"
        # 调整负夏普比率，更偏向收益
        objective = lambda w, er, cov: -sharpe_ratio(w, er, cov) * 0.8 - portfolio_expected_return(w, er) * 0.2
        objective_args = (expected_returns, cov_matrix)
        explanation = "此投资组合偏重回报，承担较高风险，适合进取型投资者"
    else:  # 极高风险
        bounds = tuple((0.05, 0.80) for _ in range(n_assets))
        title = "激进型投资组合"
        # 更强调收益而非夏普比率
        objective = lambda w, er, cov: -portfolio_expected_return(w, er)
        objective_args = (expected_returns, cov_matrix)
        explanation = "此投资组合追求最高回报，愿意承担显著风险，适合激进型投资者"
    
    constraints = {'type': 'eq', 'fun': weight_sum_constraint}
    
    result = minimize(
        objective,
        initial_weights,
        args=objective_args,
        method='SLSQP',
        bounds=bounds,
        constraints=constraints
    )
    
    weights = result['x']
    expected_return = portfolio_expected_return(weights, expected_returns)
    expected_volatility = portfolio_volatility(weights, cov_matrix)
    expected_sharpe = sharpe_ratio(weights, expected_returns, cov_matrix)
    
    return weights, title, explanation, expected_return, expected_volatility, expected_sharpe

# 提示用户输入风险评分
risk_score = int(input("请输入您的风险偏好评分(0-100)，0为最保守，100为最激进："))

# 根据风险评分生成推荐投资组合
rec_weights, rec_title, rec_explanation, rec_return, rec_volatility, rec_sharpe = recommend_portfolio(
    risk_score, expected_returns, cov_matrix, tickers
)

# 显示推荐投资组合
print(f"\n====== {rec_title} (基于LSTM预测) ======")
print(rec_explanation)
print("\n推荐投资组合权重:")
for i, ticker in enumerate(tickers):
    print(f"{ticker}: {rec_weights[i]*100:.2f}%")

print(f"预期每日收益率: {rec_return*100:.4f}%")
print(f"预期每日波动率: {rec_volatility*100:.4f}%")
print(f"预期年化收益率: {rec_return*252*100:.2f}%")
print(f"预期年化波动率: {rec_volatility*np.sqrt(252)*100:.2f}%")
print(f"夏普比率: {rec_sharpe:.4f}")

# 可视化推荐投资组合
plt.figure(figsize=(10, 10))
plt.pie(rec_weights, labels=tickers, autopct='%1.1f%%', startangle=90)
plt.title(f"{rec_title} (基于LSTM预测)", fontproperties=font, fontsize=16)
plt.show()
# Out:
# 准备股票 688981 的预测收益率...
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/4000327813.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/4000327813.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_daily_avg['Date'] = pd.to_datetime(ticker_daily_avg['Date'])
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 股票 688981 的平均预测收益率: -0.0026
#
# 准备股票 002475 的预测收益率...
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/4000327813.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/4000327813.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_daily_avg['Date'] = pd.to_datetime(ticker_daily_avg['Date'])
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 股票 002475 的平均预测收益率: 0.0313
#
# 准备股票 000524 的预测收益率...
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/4000327813.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
# /var/folders/h8/v5cmxjw939l6xq5v2v4hxgrm0000gn/T/ipykernel_70362/4000327813.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ticker_daily_avg['Date'] = pd.to_datetime(ticker_daily_avg['Date'])
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 股票 000524 的平均预测收益率: -0.0134
# 预测数据点不足，使用实际历史收益率计算协方差矩阵
#
# 各股票预期日收益率:
# 688981: 0.3561%
# 002475: 3.1311%
# 000524: -1.3573%
#
# ====== 投资组合优化结果（基于LSTM预测）======
#
# 最优夏普比率投资组合 (最佳风险收益比):
# 688981: 35.00%
# 002475: 60.00%
# 000524: 5.00%
# 预期每日收益率: 1.9354%
# 预期每日波动率: 2.2244%
# 预期年化收益率: 487.73%
# 预期年化波动率: 35.31%
# 夏普比率: 0.4205
#
# 最小波动率投资组合 (最低风险):
# 688981: 60.00%
# 002475: 24.31%
# 000524: 15.69%
# 预期每日收益率: 0.7619%
# 预期每日波动率: 1.8664%
# 预期年化收益率: 192.00%
# 预期年化波动率: 29.63%
# 夏普比率: -0.1276
# /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:437: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)
# /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:441: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   g = append(wrapped_grad(x), 0.0)
# /opt/anaconda3/lib/python3.12/site-packages/scipy/optimize/_slsqp_py.py:495: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   a_eq = vstack([con['jac'](x, *con['args'])
# 请输入您的风险偏好评分(0-100)，0为最保守，100为最激进： 77
# ====== 进取型投资组合 (基于LSTM预测) ======
# 此投资组合偏重回报，承担较高风险，适合进取型投资者
#
# 推荐投资组合权重:
# 688981: 25.00%
# 002475: 70.00%
# 000524: 5.00%
# 预期每日收益率: 2.2129%
# 预期每日波动率: 2.4171%
# 预期年化收益率: 557.66%
# 预期年化波动率: 38.37%
# 夏普比率: 0.5018
